# %%
import numpy as np
import pandas as pd
import time
import os
import openai

# %%
name_list = ['BukGu', 'DalSeongGun', 'DalSuGu', 'DongGu', 'JungGu', 'NamGu', 'SeoGu', 'SuSeongGu']
complain_list = []

# %%
def save(num):
    complain_list[num].to_csv('./크롤링/증강/complain_' + name_list[num] + '_plus_gpt.csv',index=False)

# %%
def load():
    for i, v in enumerate(name_list):
        complain_list.append(pd.read_csv('./크롤링/complain_' + v + '_plus.csv'))

# %%
load()

# %%
# %pip install torch
# Out:
# ...
#      -------------------------------------- 172.3/172.3 MB 9.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install transformers
# Out:
# ...
#      ---------------------------------------- 7.0/7.0 MB 10.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.5/3.5 MB 15.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 224.5/224.5 kB 14.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 적합하지 않은 pretrained 모델
import torch
from transformers import GPT2LMHeadModel
from transformers import PreTrainedTokenizerFast
tokenizer = PreTrainedTokenizerFast.from_pretrained("skt/kogpt2-base-v2",
  bos_token='</s>', eos_token='</s>', unk_token='<unk>',
  pad_token='<pad>', mask_token='<mask>') 

model = GPT2LMHeadModel.from_pretrained('skt/kogpt2-base-v2')
text = '안녕하세요. 마약류취급자, 원료물질수출입업자, 원료물질제조업자 폐업·휴업·재개업 신고에 대해 민원을 접수하려고 합니다.'
input_ids = tokenizer.encode(text)
gen_ids = model.generate(torch.tensor([input_ids]),
                           max_length=500,
                           repetition_penalty=2.0,
                           pad_token_id=tokenizer.pad_token_id,
                           eos_token_id=tokenizer.eos_token_id,
                           bos_token_id=tokenizer.bos_token_id,
                           use_cache=True)
generated = tokenizer.decode(gen_ids[0,:].tolist())
print(generated)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# 안녕하세요. 마약류취급자, 원료물질수출입업자, 원료물질제조업자 폐업·휴업·재개업 신고에 대해 민원을 접수하려고 합니다.</d> 지난해 12월 31일 오후 2시께 서울 강남구 역삼동 한 아파트에서 A(50)씨가 숨져 있는 것을 이웃 주민이 발견, 경찰에 신고, 경찰이 출동했다.
# A씨는 이날 오전 9시경 자신의 집에서 목을 매 스스로 목숨을 끊은 것으로 알려졌다.
# 경찰 관계자는 "숨진 B씨의 사인은 타살로 추정된다"며 "이웃 주민 C씨도 함께 자살한 것 같다"고 말했다.
# B씨와 같은 아파트에 사는 주민들은 평소 우울증을 앓아온 터라 이번 사건이 극단적인 선택을 할 수 있다는 우려를 하고 있다.
# 특히 최근 들어 자살을 시도하는 사람들이 늘고 있어 더욱 불안하다.
# 지난달 30일에는 경기도 부천시의 모 빌라에서 40대 남성이 흉기에 찔려 살해되는 등 올들어만 모두 4건의 살인사건이 발생했다.
# 또 최근에는 인천의 또 다른 주택에서도 20대가 휘두른 칼과 둔기로 인해 중상을 입는 사고가 발생하기도 했다.
# 이에 따라 각 지자체에서는 '묻지도 따지지 않고' 살인을 막을 대책을 마련하고 있지만 실효성이 떨어진다는 지적이다.
# 실제로 서울시내 자치구들은 범죄예방을 위해 순찰을 강화하는 한편 예방활동을 강화하고 있으나 정작 이를 위한 예산은 턱없이 부족한 실정이다.
# ...

# %%
# %pip install openai
# Out:
# ...
#      ---------------------------------------- 70.3/70.3 kB 3.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 323.6/323.6 kB 10.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.7/61.7 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
for i, v in enumerate(name_list):
    print(v, complain_list[i].shape)
# Out:
# BukGu (94, 2)
# DalSeongGun (112, 2)
# DalSuGu (67, 2)
# DongGu (93, 2)
# JungGu (81, 2)
# NamGu (62, 2)
# SeoGu (57, 2)
# SuSeongGu (88, 2)

# %%
for i, v in enumerate(name_list):
    print(v)
    print(complain_list[i]['dept'].value_counts())
    print()
# Out:
# BukGu
# 신성장전략국 민생경제과       9
# 주민생활지원국 경제통상과      9
# 도시국 건설과            8
# 복지국 경제진흥과          7
# 주민생활지원국 환경관리과      6
# 주민생활지원국 주민복지과      6
# 신성장전략국 일자리정책과      5
# 행정국 민원여권과          5
# 도시국 건축주택과          4
# 보건소 위생과            4
# 도시국 교통과            4
# 문화녹지국 공원녹지과        3
# 주민생활지원국 주민생활지원과    2
# 도시국 도시관리과          2
# 도시국 도시경관과          2
# 문화공보실              2
# 복지환경국 환경관리과        2
# 복지환경국 여성아동과        2
# 복지환경국 희망복지과        2
# 도시국 토지정보과          2
# 보건소 건강증진과          1
# 문화녹지국 교육청소년과       1
# 행정국 재무과            1
# 읍/면/동사무소           1
# 총무국 문화교육과          1
# 안전행정국 세무2과         1
# 안전행정국 총무과          1
# 보건소 보건과            1
# Name: dept, dtype: int64
#
# DalSeongGun
# 행정관리국 종합민원과      7
# 자치행정국 종합민원과      7
# 주민복지국 농업정책과      6
# 주민복지국 환경과        5
# 주민생활지원국 환경관리과    5
# 주민복지국 교통과        4
# 경제환경국 일자리경제과     4
# 보건소 보건과          4
# 경제정책실            3
# 주민지원국 경제지원과      3
# 건설도시국 건축과        3
# 주민복지국 사회복지과      3
# 경제환경국 교통과        3
# 건설도시국 건설과        3
# ...

# %%
openai.api_key = "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"

# 각 구, 군
for i in range(3, len(name_list)):
    #i = 1

    print(name_list[i])

    # 각 민원 내용
    df = complain_list[i]

    # gpt 생성문장 저장할 리스트
    gpt_content_list = []
    gpt_dept_list = []
    
    
    for j in df.values:

        content = j[0]
        dept = j[1]

        #print(content, dept)

        # 과 - 민원처리 내용 함께 전달
        q1 = f"'{content}' 와 관련된 주민 민원 문장을 만들어줘. 이 민원은 공공기관의 '{dept}' 에서 처리할 거야. \
        '{dept}' 는 직접적으로 언급하진 말아줘.\
        민원 신청 문장에서 형식적인 인사말은 빼줘. (ex. 존경하는 공공기관 담당자 여러분께 등 ) \
        결과만 말해줘."

        completion = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "user", "content": q1}
            ],
            # # n 개 문장 간의 유사도 (반비례)
            # temperature = 0.7,
            # n = 2
        )

        print(dept, content, '/', completion.choices[0].message.content)
        gpt_content_list.append(completion.choices[0].message.content)
        gpt_dept_list.append(dept)

        # gpt는 1분에 3개씩 가능.
        time.sleep(20)

        # 민원처리 내용만 전달
        q2 = f"'{content}' 와 관련된 주민 민원 문장을 만들어줘.  \
        민원 신청 문장에서 형식적인 인사말은 빼줘. (ex. 존경하는 공공기관 담당자 여러분께 등 ) \
        결과만 말해줘."

        completion = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "user", "content": q2}
            ],
        ) 

        print(dept, content, '/', completion.choices[0].message.content)
        gpt_content_list.append(completion.choices[0].message.content)
        gpt_dept_list.append(dept)

        time.sleep(20)

    #수집한 정보를 데이터 프레임으로 저장
    df_temp = pd.DataFrame({'content': gpt_content_list,
                   'dept': gpt_dept_list
                })

    # 증강 결과를 추가
    complain_list[i] = pd.concat([complain_list[i], df_temp])

    save(i)
# Out:
# DongGu
# 경제복지국 경제지원과 동물용 의약품 제조관리자(수입관리자·관리약사) 변경신고 / 동물용 의약품 제조관리자(수입관리자·관리약사) 변경신고를 해야합니다. 해당 인력이 업무를 담당하던 기업에서 퇴사하고 새로운 담당자가 부임하게 되어 변경신고를 하고자 합니다. 신규 담당자의 정보는 따로 알려드리겠습니다. 이에 대한 처리 부탁드립니다.
# 경제복지국 경제지원과 동물용 의약품 제조관리자(수입관리자·관리약사) 변경신고 / 동물용 의약품 제조관리자(수입관리자·관리약사) 변경사항에 대해 신고합니다. 변경된 제조관리자는 [이름]이며, 변경일은 [날짜]입니다. 이에 따라 새로운 제조관리자와의 소통 및 협조를 부탁드립니다. 감사합니다.
# 도시안전국 공원녹지과 입목등록 / 저는 XX 구민이며, 우리 동네에 있는 XX 공원 주변에 나무가 죽어나가고 있습니다. 이에 따라 동네 주민들끼리 모여 나무를 심고 관리하려고 하는데, 이를 위해 입목등록 신청을 하고자 합니다. 빠른 처리 부탁드립니다.
# 도시안전국 공원녹지과 입목등록 / 저는 입목등록을 신청하고 싶습니다. 어떻게 절차를 진행해야 하나요?
# 행정문화국 민원여권과 의료기기영업 휴업·폐업·재개 신고 / 저는 의료기기 판매 회사에서 일하고 있는 주민입니다. 회사가 휴업하거나 폐업하거나 재개할 때에는 의료기기영업 휴업·폐업·재개 신고를 해야 한다고 알고 있습니다. 이와 관련하여 어떤 절차를 따라야 하는지 자세히 알고 싶습니다. 처리 부탁드립니다.
# 행정문화국 민원여권과 의료기기영업 휴업·폐업·재개 신고 / 의료기기영업을 하고 있는데 휴업, 폐업, 또는 재개 신고를 하려 합니다. 어떻게 절차를 진행해야 할지 안내해주세요.
# ...

# %%
openai.api_key = "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"
dept = complain_list[5].iloc[20]['dept']
content = complain_list[5].iloc[20]['content']

q1 = f"'{content}' 와 관련된 주민 민원 문장을 만들어줘. 이 민원은 공공기관의 '{dept}' 에서 처리할 거야.  \
        '{dept}' 는 직접적으로 언급하진 말아줘.\
        민원 신청 문장에서 형식적인 인사말은 빼줘. (ex. 존경하는 공공기관 담당자 여러분께, 안녕하세요 등 ) \
        결과만 말해줘."

#print(q1)

completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": q1}
    ],
    # # n 개 문장 간의 유사도 (반비례)
    # temperature = 0.7,
    # n = 2
)

print(dept, '/', content, '/', completion.choices[0].message.content)
# Out:
# 주민행복국 행복정책과 / 사회복지법인 정관변경인가 / 사회복지법인 정관 변경이 주민들에게 피해를 줄 수 있다는 우려가 있어 처리해 주시기를 요청합니다. 해당 변경으로 인해 지역 사람들의 삶에 영향이 크게 미칠 수 있으며, 이에 대한 충분한 검토와 설명이 필요합니다. 또한, 주민들의 의견 수렴을 통해 전반적인 이익을 고려한 결정을 내려주시기를 바랍니다.

# %%
#print(completion.choices[0].message.content)

# %%
complain_list[0].iloc[5]
# Out:
# content    정신요양시설 설치허가 및 허가사항 변경통지
# dept                   복지환경국 희망복지과
# Name: 5, dtype: object

# %%
complain_list[0].head()
# Out:
#                             content           dept
# 0                           건설업상속신고  신성장전략국 일자리정책과
# 1  가축분뇨관련영업 [허가신청서, 변경허가신청서, 변경신고서]    복지환경국 환경관리과
# 2                       개별공시지가 이의신청      도시국 토지정보과
# 3               통신판매업 휴업·폐업·영업재개 신고      행정국 민원여권과
# 4                    지식산업센터설립(변경)승인  신성장전략국 일자리정책과
