# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn

# %%
bukgu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_BukGu3.csv')
DalSeongGun = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_DalSeongGun.csv')
DalSugu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_DalSugu.csv')
DongGu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_DongGu.csv')
JungGu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_JungGu.csv')
NamGu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_NamGu.csv')
Seogu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_Seogu.csv')
Suseonggu = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/데이터 수집/크롤링/complain_Suseong.csv')

# %%
complain_list = []
name_list = ['bukgu', 'DalSeongGun', 'DalSugu', 'DongGu', 'JungGu', 'NamGu', 'Seogu', 'Suseonggu']

complain_list.append(bukgu)
complain_list.append(DalSeongGun)
complain_list.append(DalSugu)
complain_list.append(DongGu)
complain_list.append(JungGu)
complain_list.append(NamGu)
complain_list.append(Seogu)
complain_list.append(Suseonggu)

# %%
bukgu.head()
# Out:
#                                           title  \
# 0                       매천동 청구장미아파트,삼우그린 입구 불합리
# 1                                     처리중..언제까지
# 2                                          도로개설
# 3  북구청장감사실은 뭐 하는 곳 입니까? 묻습니다. 불법에 대한 최고의 북구 전문가
# 4   대구시장 북구청장 감사실은 뭐 하는 부서 입니까? 감사실 폐쇄하셔요? 미관지구
#
#                                              content       dept
# 0  위치 : 매천동 청구장미아파트,삼우그린아파트 들어가는 입구 (매천생활용품 바로 옆 ...    도시국 건설과
# 1  어린이보호구역 불법주차 불법적재 신고한지가 언제인데 아직 처리중...\r\n적재물도...  도시국 도시행정과
# 2  본인은 대구시 북구 태전동 81-1, 74, 75번지 토지 소유자 입니다.\r\n현...    도시국 건설과
# 3  북구청장\r\n\r\n감사실은 뭐 하는 곳 입니까? 묻습니다. 불법에 대한 최고의 ...        감사실
# 4  대구시장 북구청장\r\n\r\n감사실은 뭐 하는 부서 입니까? 감사실 폐쇄하셔요?\...        감사실

# %%
bukgu.iloc[0]['content']
# Out:
# '위치 : 매천동 청구장미아파트,삼우그린아파트 들어가는 입구 (매천생활용품 바로 옆 진입로)\r\n내용: 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음.(자동차 우측 사각지대 + 늦은밤 어두컴컴한 거리) 꼭! 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다. 사진도 첨부합니다.\r\n\r\n※ 첨부파일 :\r\nIMG_2181.jpeg\r\nIMG_2182.jpeg'

# %%
for i, v in enumerate(name_list):
    print(v, complain_list[i].shape)
# Out:
# bukgu (9237, 3)
# DalSeongGun (2764, 3)
# DalSugu (5862, 3)
# DongGu (4894, 3)
# JungGu (3026, 3)
# NamGu (2782, 3)
# Seogu (2663, 3)
# Suseonggu (7616, 3)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
for i, v in enumerate(name_list):
    print(v)
    print(complain_list[i]['dept'].value_counts())
    print()
# Out:
# bukgu
# 감사실                2235
# 도시국 건축주택과          1186
# 도시국 교통과            1121
# 도시국 건설과            1038
# 주민생활지원국 환경관리과       437
# 도시국 도시관리과           391
# 도시국 재난안전과           365
# 복지환경국 자원순환과         358
# 복지환경국 환경관리과         324
# 문화녹지국 공원녹지과         223
# 보건소 위생과             196
# 도시국 도시행정과           100
# 문화공보실                80
# 주민생활지원국 주민생활지원과      76
# 행정국 문화체육과            76
# 총무국 총무과              68
# 주민생활지원국 경제통상과        58
# 보건소 보건과              57
# 보건소 보건위생과            57
# 주민생활지원국 주민복지과        55
# 행정국 행정지원과            52
# 도시국 토지정보과            47
# 신성장전략국 민생경제과         46
# 도시재생추진단 일자리경제과       36
# 문화녹지국 체육진흥과          33
# 도시국 재해예방과            31
# 총무국 문화교육과            31
# 총무국 민원봉사과            28
# 보건소 보건행정과            27
# 복지국 경제진흥과            26
# 총무국 정보산업과            24
# 총무국 세무2과             23
# 문화녹지국 문화예술과          19
# 도시국 도시안전과            17
# 행정국 정보통신과            17
# 행정국 민원여권과            16
# 복지환경국 여성아동과          16
# 안전행정국 문화교육과          13
# ...

# %%
len(bukgu.loc[bukgu['dept'].str.endswith(('읍', '면', '동')), 'dept'])
# Out:
# 98

# %%
for i, v in enumerate(name_list):
    complain_list[i].loc[complain_list[i]['dept'].str.endswith(('읍', '면', '동')), 'dept'] = '읍/면/동사무소'

# %%
for i, v in enumerate(name_list):
    print(v, complain_list[i].shape)
    print(complain_list[i]['dept'].value_counts())
    print()
# Out:
# bukgu (9236, 2)
# 감사실                2235
# 도시국 건축주택과          1186
# 도시국 교통과            1121
# 도시국 건설과            1038
# 주민생활지원국 환경관리과       437
# 도시국 도시관리과           391
# 도시국 재난안전과           365
# 복지환경국 자원순환과         358
# 복지환경국 환경관리과         324
# 문화녹지국 공원녹지과         223
# 보건소 위생과             196
# 도시국 도시행정과           100
# 읍/면/동사무소             98
# 문화공보실                80
# 주민생활지원국 주민생활지원과      76
# 행정국 문화체육과            76
# 총무국 총무과              68
# 주민생활지원국 경제통상과        58
# 보건소 보건위생과            57
# 보건소 보건과              57
# 주민생활지원국 주민복지과        55
# 행정국 행정지원과            52
# 도시국 토지정보과            47
# 신성장전략국 민생경제과         46
# 도시재생추진단 일자리경제과       36
# 문화녹지국 체육진흥과          33
# 도시국 재해예방과            31
# 총무국 문화교육과            31
# 총무국 민원봉사과            28
# 보건소 보건행정과            27
# 복지국 경제진흥과            26
# 총무국 정보산업과            24
# 총무국 세무2과             23
# 문화녹지국 문화예술과          19
# 도시국 도시안전과            17
# 행정국 정보통신과            17
# 복지환경국 여성아동과          16
# ...

# %%
# 제목 + 내용 합치기
for i, v in enumerate(name_list):
    complain_list[i]['content'] = complain_list[i]['title'] + ' ' + complain_list[i]['content']
    complain_list[i] = complain_list[i].drop(['title'], axis=1)

# %%
complain_list[1]
# Out:
#                                                 content          dept
# 0     다사 금호 어울림 옥외등 다사 금호어울림 아파트 옥외등 불빛이 너무 많이 밝습니다\...     건설도시국 건축과
# 1     미진이지비아 옆 옹벽 데크경사로 오토바이진입금지 팻말설치요청 안녕하세요.\n미진이지...   건설도시국 안전총괄과
# 2     이정표 전도 이정표 전도(부목)\n\n※ 첨부파일 :\nScreenshot_2023...   문화관광국 공원녹지과
# 3     인도블럭에 무성한 잡초 및 땅으로 뻗어있는 가로수 가지등을 정비해 주실것을 요청. ...     건설도시국 건설과
# 4     구지 국가산단 46길 주차장소 교통장애 국지국가 산단 46길 32길 교차로 부근 인...     경제환경국 교통과
# 5     달성군 논공읍 북리, 남리 (달성1차 산업단지) 공공도서관 설립요청드립니다 달성군에...   교육복지국 교육정책과
# 6     투명유리벽 수리 구지에 삽니다.\n제가 주로 이용하는 버스정류장이 국가산단이다음역입...     건설도시국 건설과
# 7     사문진 높이100m 전망대 설치 전옥포출신 군수때 부터 달성군 행정 쭈욱 지켜보면 ...     문화관광국 관광과
# 8     다사 금호 어울림 전기차 충전기사용 못하게합니다. 이번에 다사금호어울림 입주한 입주...     경제환경국 환경과
# 9     버스 승강장 원상복구 요청 다사역 1번출구 버스 승강장 원상복구요청.\n금호어울림 ...     경제환경국 교통과
# 10    대형트럭이 오가는 도로 뿐이라 한울안중학교 아이들과 동네어른들이 오가는 길이 위험해...     건설도시국 건설과
# 11    가로등 전등 조치 요망 현풍읍 국가산단북로 110 길 집앞 가로등이 며칠째 켜지지 ...   건설도시국 도시정비과
# ...

# %%
# 부서가 '-' 인 것 제외
for i, v in enumerate(name_list):
    complain_list[i] = complain_list[i].drop(complain_list[i].loc[complain_list[i]['dept'] == '-'].index)

# %%
complain_list[5]['content'].str.contains('테스트').value_counts()
# Out:
# False    2777
# True        5
# Name: content, dtype: int64

# %%
# 테스트 게시물 제외
for i, v in enumerate(name_list):
    complain_list[i] = complain_list[i].loc[~complain_list[i]['content'].str.contains('테스트', na=False)]

# %%
complain_list[5]['content'].str.contains('테스트').value_counts()
# Out:
# False    2777
# Name: content, dtype: int64

# %%
bukgu['content'].apply(lambda x : x.split('첨부파일')[0])[0]
# Out:
# '매천동 청구장미아파트,삼우그린 입구 불합리 위치 : 매천동 청구장미아파트,삼우그린아파트 들어가는 입구 (매천생활용품 바로 옆 진입로)\r\n내용: 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음.(자동차 우측 사각지대 + 늦은밤 어두컴컴한 거리) 꼭! 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다. 사진도 첨부합니다.\r\n\r\n※ '

# %%
for i, v in enumerate(name_list):
    print(complain_list[i].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9229 entries, 0 to 9236
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  9229 non-null   object
#  1   dept     9229 non-null   object
# dtypes: object(2)
# memory usage: 216.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2761 entries, 0 to 2763
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  2761 non-null   object
#  1   dept     2761 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5858 entries, 0 to 5861
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  5858 non-null   object
#  1   dept     5858 non-null   object
# dtypes: object(2)
# memory usage: 137.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# 첨부파일 ~ 문자열 삭제
for i, v in enumerate(name_list):
    complain_list[i]['content'] = complain_list[i]['content'].astype(str).apply(lambda x : x.split('첨부파일')[0])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18012\4225785745.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complain_list[i].loc[:,'content'] = complain_list[i].loc[:,'content'].astype(str).apply(lambda x : x.split('첨부파일')[0])

# %%
complain_list[0].iloc[0]['content']
# Out:
# '매천동 청구장미아파트,삼우그린 입구 불합리 위치 : 매천동 청구장미아파트,삼우그린아파트 들어가는 입구 (매천생활용품 바로 옆 진입로)\r\n내용: 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음.(자동차 우측 사각지대 + 늦은밤 어두컴컴한 거리) 꼭! 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다. 사진도 첨부합니다.\r\n\r\n※ '

# %%
# 정규표현식 사용, 불용어 제거
import re
def get_only_hangul(line):
	parseText= ''.join(re.compile('[ |가-힣]*').findall(line))

	return parseText

# %%
bukgu.iloc[0]['content']
# Out:
# '위치 : 매천동 청구장미아파트,삼우그린아파트 들어가는 입구 (매천생활용품 바로 옆 진입로)\r\n내용: 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음.(자동차 우측 사각지대 + 늦은밤 어두컴컴한 거리) 꼭! 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다. 사진도 첨부합니다.\r\n\r\n※ 첨부파일 :\r\nIMG_2181.jpeg\r\nIMG_2182.jpeg'

# %%
get_only_hangul(bukgu.iloc[0]['content'])
# Out:
# '위치  매천동 청구장미아파트삼우그린아파트 들어가는 입구 매천생활용품 바로 옆 진입로내용 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음자동차 우측 사각지대  늦은밤 어두컴컴한 거리 꼭 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다 사진도 첨부합니다 첨부파일 '

# %%
for i, v in enumerate(name_list):
    complain_list[i]['content'] = complain_list[i]['content'].apply(lambda x : get_only_hangul(x))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18012\1440008266.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complain_list[i]['content'] = complain_list[i]['content'].apply(lambda x : get_only_hangul(x))

# %%
complain_list[0].iloc[0]['content']
# Out:
# '매천동 청구장미아파트삼우그린 입구 불합리 위치  매천동 청구장미아파트삼우그린아파트 들어가는 입구 매천생활용품 바로 옆 진입로내용 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음자동차 우측 사각지대  늦은밤 어두컴컴한 거리 꼭 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다 사진도 첨부합니다 '

# %%
def save():
    for i, v in enumerate(name_list):
        complain_list[i].to_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/전처리/경현/' + v + '.csv',index=False)

# %%
save()

# %%
complain_list = []

# %%
for i, v in enumerate(name_list):
    complain_list.append(pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/전처리/경현/' + v + '.csv'))

# %%
temp.iloc[0]['content']
# Out:
# '매천동 청구장미아파트삼우그린 입구 불합리 위치  매천동 청구장미아파트삼우그린아파트 들어가는 입구 매천생활용품 바로 옆 진입로내용 사람들이 자주 이용하는 횡단보도가 있고 아파트로 들어가는 차량들이 많이 다님에도 불구하고 새벽에 매천생활용품점과 자동차수리점이 문을 닫는 시간이 되면 거리가 너무 어두컴컴해서 보행자를 칠 우려가 있음자동차 우측 사각지대  늦은밤 어두컴컴한 거리 꼭 매천생활용품점과 자동차수리점이 문을 닫는 시간 대 거리에 조명시설 확인 후 조치해야할 것입니다 사진도 첨부합니다 '

# %%
temp = pd.read_csv('C:/Users/User/Desktop/경현/프로젝트/민원/Daegu_Complain_Classifficaion/전처리/경현/bukgu.csv')

# %%
temp.head()
# Out:
#                                              content       dept
# 0  매천동 청구장미아파트삼우그린 입구 불합리 위치  매천동 청구장미아파트삼우그린아파트 ...    도시국 건설과
# 1  처리중언제까지 어린이보호구역 불법주차 불법적재 신고한지가 언제인데 아직 처리중적재물...  도시국 도시행정과
# 2  도로개설 본인은 대구시 북구 태전동   번지 토지 소유자 입니다현재 상기 토지에서 ...    도시국 건설과
# 3  북구청장감사실은 뭐 하는 곳 입니까 묻습니다 불법에 대한 최고의 북구 전문가 북구청...        감사실
# 4  대구시장 북구청장 감사실은 뭐 하는 부서 입니까 감사실 폐쇄하셔요 미관지구 대구시장...        감사실

# %%
temp.loc[temp.duplicated()]
# Out:
#                                                 content         dept
# 25    북구청장감사실은 뭐 하는 곳 입니까 묻습니다 불법에 대한 최고의 북구 전문가 북구청...          감사실
# 26    대구시장 북구청장 감사실은 뭐 하는 부서 입니까 감사실 폐쇄하셔요 미관지구 대구시장...          감사실
# 27    북구청장 주거환경정비 해당주민 반대에 전화 문자 카톡 구민재산 생활 고통종식하라 본...    도시국 건축주택과
# 28    북구청장 전 전보다 못한 행정 북구 전문가인가 상식있는 구민은 알고 한탄한다 북구청...      보건소 위생과
# 29    북구청장 재활용쓰레기 처리 못 하는게 경영의 최고 전문가 인가 평가는 구민이 북구청...  복지환경국 자원순환과
# ...                                                 ...          ...
# 6476  국내자매도시 운영계획을 보고 국내 자매도시 곳 가운데 시 직영이나 위탁 받은 단체에...      총무국 총무과
# 7488  상가에서 인도에 진열해놓은 물건좀 치워주세요 저는 부영 단지에 사는 주민입니다다름이...    도시국 재난안전과
# 7491  서변초등학교입구 왕복차선 도로인 스쿨죤 지역 불법주차 시정 평소 구청 교통행정에 수...      도시국 교통과
# 8655  밑에 이어 사진자료  민원 사진 자료 입니다 횡단 보도 한번 보십시요버스승강장 한번...    도시국 재난안전과
# 8656  밑에 이어 사진자료  민원 사진 자료 입니다 횡단 보도 한번 보십시요버스승강장 한번...    도시국 재난안전과
#
# [1266 rows x 2 columns]

# %%
for i, v in enumerate(complain_list):
    v[i] =
