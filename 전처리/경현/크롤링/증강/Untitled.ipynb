# %%
# !pip install pymongo

### Pymongo
- mongdb를 python 에서 사용할 수 있도록 도와주는 패키지
- connect > server > database > collection
- document: CRUD

import pymongo
import pandas as pd

### connect server(client)

client = pymongo.MongoClient('mongodb://kt:ktpw@13.125.184.173:27017')
client

list(client.list_databases())

### connect database(mongo)

db = client.mongo
db

#### Collection - CRUD

# read collection
list(db.list_collection_names())

# create collection
collection = db.info2
collection

# update cllection
db.user.rename('users')

list(db.list_collection_names())

# delete collection
db.info1.drop()

list(db.list_collection_names())

#### Document - CRUD

# READ Documents

# select collection
collection = db.info

# select one document
document = collection.find_one({'subject' : 'python'})
document

# select many documents
documents = collection.find({'subject' : 'python'})
data = list(documents)
data

# make datafram object
pd.DataFrame(data)

# 한 번 사용하면 사라짐. 데이터를 변수에 넣어 저장해야 함.
# disappear documents
list(documents)

# READ 
documents = collection.find({'level' : {'$gte' : 5}}).sort('level', pymongo.DESCENDING)
pd.DataFrame(list(documents))

pymongo.DESCENDING

# CREATE documents
data = {'subject': 'gulp', 'level' : 4}

# insert one data
result = collection.insert_one(data)
print(result.inserted_id)

documents = collection.find()
pd.DataFrame(list(documents)).tail(3)

# insert many data
data = [
    {'subject': 'webpack', 'level' : 7},
    {'subject': 'java', 'level' : 6},
]
result = collection.insert_many(data)
print(result.inserted_ids)

documents = collection.find()
pd.DataFrame(list(documents)).tail(3)

documents = collection.find().skip(3).limit(2)
pd.DataFrame(list(documents))

# UPDATE : documents
collection.update_many({'subject': 'webpack'}, {'$set' : {'level': 9}})

documents = collection.find({'subject' : 'webpack'})
pd.DataFrame(list(documents))

# DELETE : documents : delete()
collection.delete_many({'level': {'$gte' : 7}})

documents = collection.find()
pd.DataFrame(list(documents))

# mongodb > dict, json
# json format > insert easy

# !pip install geohash2

import zigbang as zb

data = zb.oneroom('망원동')
data.tail(2)

# dataframe > list of dict
json_data = data.to_dict('records')
json_data[:2]

# user > db > collection > data
client.zigbang.onroom.insert_many(json_data)
