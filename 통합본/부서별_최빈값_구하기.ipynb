# %% [markdown]
# <a href="https://colab.research.google.com/github/eleron7/Daegu_Complain_Classifficaion/blob/main/%EB%B6%80%EC%84%9C%EB%B3%84_%EC%B5%9C%EB%B9%88%EA%B0%92_%EA%B5%AC%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **‼처음부터 실행하지 말고, 각 파트 끝에 데이터를 저장하고, 다음 파트 담당자는 해당 데이터를 불러와서 작업할 것**
# - 각 load, save 함수 사용

# %%
name_list = ['BukGu', 'DalseongGun', 'DalsuGu', 'DongGu', 'JungGu', 'NamGu', 'SeoGu', 'Suseonggu']
complain_list = []

# %%
def save():
    for i, v in enumerate(name_list):
        complain_list[i].to_csv(v + '.csv',index=False)

# %%
def load():
    for i, v in enumerate(name_list):
        complain_list.append(pd.read_csv(v + '.csv'))

# %% [markdown]
# # 0. 라이브러리, row data 불러오기

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ----

# %% [markdown]
# ## 7.부서별 최빈 단어 찾기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
name_list
# Out:
# ['BukGu',
#  'DalseongGun',
#  'DalsuGu',
#  'DongGu',
#  'JungGu',
#  'NamGu',
#  'SeoGu',
#  'Suseonggu']

# %%
def load_for_corab():
    for i, v in enumerate(name_list):
        complain_list.append(pd.read_csv('/content/drive/MyDrive/벨류업 프로젝트 공모전/alldata/'+ v + '.csv'))

# %%
load_for_corab()

# %%
#그냥 날려버리기
complain_list[3].drop(2262,axis=0,inplace=True)
complain_list[6].drop(1625,axis=0,inplace=True)

# %%
complain_list[3].drop('index',axis=1,inplace=True)
complain_list[6].drop('index',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1fc5f6402323> in <cell line: 1>()
# ----> 1 complain_list[3].drop('index',axis=1,inplace=True)
#       2 complain_list[6].drop('index',axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
complain_list[3].reset_index(inplace=True)
complain_list[6].reset_index(inplace=True)

# %%
complain_list[6]
# Out:
#                                                 content         dept
# 0     매번 수거 하시는 분들만 수고하시네요 동일고충민원여부동일고충민원여부  선행민원번호 ...     읍/면/동사무소
# 1     비대면 처방전 거부한 약국 있습니다 아이가 콧물 감기로 아프기시작해서비대면 처방을받...    보건소 보건행정과
# 2     전봇대 우째 좀 안됩니까  가 설치 되어도 무단 투기가 개선 되지 않는 건 전봇대가...     읍/면/동사무소
# 3     평리구역서대구 영무예다음 부실 시공 등 시공사 소극적 조치에 대한 민원 우리 서구의...  도시안전국 건축주택과
# 4     여름철대비 비산동에 사는 주민입니다 공무에 힘쓰시느라 수고가 많으십니다 비산동이 주...    보건소 보건행정과
# ...                                                 ...          ...
# 2369  저 저번에 질문한 사람인데요 죄송하지만 우편물이 또 그사람 이름으로 날라왔거든요그일...     읍/면/동사무소
# 2370  뭐좀 물어볼려구요 저기요집으로 다른사람이름으로 음식물쓰레기 수수료 국민 건강보험 독...     읍/면/동사무소
# 2371  소음 및 분진 피해삼육비철 구정에 고생이 많으십니다저는 서구 원대가 번지에 처와 개...  사회산업국 환경관리과
# 2372  서구청 귀청의 전력 에너지 사용량 자료 요청 귀청의 무한한 발전을 기원합니다안녕하십...    도시국 건축주택과
# 2373  토지대장과건물대장이 같은것인가요 건강보험공단에서 건물대장을 떼오라는데 토지대장과 같...    도시국 건축주택과
#
# [2374 rows x 2 columns]

# %%
#형태소 분석할  after열 생성
for i in range(0,len(complain_list)):
  complain_list[i]['after']=complain_list[i]['content'].copy()

# %%
# !pip install konlpy pandas seaborn gensim wordcloud python-mecab-ko wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.8.2.2)
# Collecting python-mecab-ko
#   Downloading python_mecab_ko-1.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (573 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.9/573.9 kB 46.0 MB/s eta 0:00:00
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 42.0 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (8.4.0)
# Collecting python-mecab-ko-dic
#   Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=de149afa669828aeb90718a806c96ae47aa26f6b4f96803587a807a5128dfd17
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-mecab-ko-dic, python-mecab-ko, JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0 python-mecab-ko-1.3.3 python-mecab-ko-dic-2.1.1.post2 wget-3.2

# %%
from konlpy.tag import *
mecab = MeCab()
# hannanum = Hannanum()

# %%
mecab.nouns('나는 배가 고파서 햄버거 조졌다,이것은 햄버거야')
# Out:
# ['나', '배', '햄버거', '이것', '햄버거']

# %%
complain_list[0].head(10)
# Out:
#                                              content         dept  \
# 0  매천동 청구장미아파트삼우그린 입구 불합리 위치  매천동 청구장미아파트삼우그린아파트 ...      도시국 건설과
# 1  처리중언제까지 어린이보호구역 불법주차 불법적재 신고한지가 언제인데 아직 처리중적재물...    도시국 도시행정과
# 2  도로개설 본인은 대구시 북구 태전동   번지 토지 소유자 입니다현재 상기 토지에서 ...      도시국 건설과
# 3  북구청장감사실은 뭐 하는 곳 입니까 묻습니다 불법에 대한 최고의 북구 전문가 북구청...          감사실
# 4  대구시장 북구청장 감사실은 뭐 하는 부서 입니까 감사실 폐쇄하셔요 미관지구 대구시장...          감사실
# 5  북구청장 주거환경정비 해당주민 반대에 전화 문자 카톡 구민재산 생활 고통종식하라 본...    도시국 건축주택과
# 6  북구청장 재활용쓰레기 처리 못 하는게 경영의 최고 전문가 인가 평가는 구민이 북구청...  복지환경국 자원순환과
# 7  북구청장 최고의 전문가 행정이 북구민에게 어디까지 미치나요 답변해 주셔요 북구청장북...          감사실
# 8  칠성초 횡단보도부근 및 침산동 일대 공사마무리를 서둘러주시기 바랍니다 침산동 국민은...      도시국 건설과
# 9  에어간판으로 인한 교통사고유발 민원을 넣었지만 해결되지 않았습니다 동일고충민원여부동...    도시국 도시행정과
#
#                                                after
# 0  [매천동, 청구장미아파트삼우그린, 입구, 불합리, 위치, 매천동, 청구장미아파트삼우...
# 1  [처리중언제, 어린이보호구역, 불법주차, 불법적재, 지, 언제, 처리중적재물, 그대...
# 2  [도로개설, 본인, 대구시, 북구, 태전동, 토지, 소유자, 입니다현재, 상기, 토...
# 3  [북구청장감사실, 뭐, 곳, 불법, 최고, 북구, 전문가, 북구청장감사실, 뭐, 곳...
# 4  [대구시장, 북구청장, 감사실, 뭐, 부, 감사, 폐쇄, 미관지구, 대구시장, 북구...
# 5  [북구청장, 주거환경정비, 해당주민, 반대, 전화, 문자, 카톡, 구민재산, 생활,...
# 6  [북구청장, 재활용쓰레기, 처리, 경영, 최고, 전문, 평, 구민, 북구청장감사실,...
# 7  [북구청장, 최고, 전문, 행정, 북구민, 어디, 답변, 북구청장북구청비서실, 구민...
# 8  [칠성초, 횡단보도부근, 침산동, 일대, 공사마무리, 침산동, 국민은행부근, 하수관...
# 9  [판, 교통사고유발, 민원, 해결, 동일고충민원여부동일고충민원여부, 선행민원번호, ...

# %%
#명사만 추출해버리기
error_list=[]
for i in range(0,len(complain_list)):
  for j in range(0,len(complain_list[i]['after'])):
    complain_list[i]['after'][j]=mecab.nouns(complain_list[i]['content'][j])

# %%
#각 지역+각 부서명을 변수이름으로 하는 리스트들을 만들어 거기에 명사들을 넣어주자
complain_list[0]['dept'].unique()
# Out:
# array(['도시국 건설과', '도시국 도시행정과', '감사실', '도시국 건축주택과', '복지환경국 자원순환과',
#        '복지환경국 환경관리과', '도시국 교통과', '문화녹지국 공원녹지과', '읍/면/동사무소', '도시국 도시관리과',
#        '주민생활지원국 환경관리과', '도시국 재난안전과'], dtype=object)

# %%
#dept에 띄어쓰기가 있어서 리스트 명으로 못쓰니까 띄어쓰기를 '_'로 바꿔줄게요

for i in range(0,len(complain_list)):
  complain_list[i]['after_dept']=complain_list[i]['dept'].copy()

error_list=[]
for j in range(0,len(complain_list)):
  for k in range(0,len(complain_list[j]['after_dept'])):
    try:
      complain_list[j]['after_dept'][k]=complain_list[j]['after_dept'][k].replace(" ","_")
    except:
      error_list.append([j,k])
      continue

# %%
complain_list[0].head(10)
# Out:
#                                              content         dept  \
# 0  매천동 청구장미아파트삼우그린 입구 불합리 위치  매천동 청구장미아파트삼우그린아파트 ...      도시국 건설과
# 1  처리중언제까지 어린이보호구역 불법주차 불법적재 신고한지가 언제인데 아직 처리중적재물...    도시국 도시행정과
# 2  도로개설 본인은 대구시 북구 태전동   번지 토지 소유자 입니다현재 상기 토지에서 ...      도시국 건설과
# 3  북구청장감사실은 뭐 하는 곳 입니까 묻습니다 불법에 대한 최고의 북구 전문가 북구청...          감사실
# 4  대구시장 북구청장 감사실은 뭐 하는 부서 입니까 감사실 폐쇄하셔요 미관지구 대구시장...          감사실
# 5  북구청장 주거환경정비 해당주민 반대에 전화 문자 카톡 구민재산 생활 고통종식하라 본...    도시국 건축주택과
# 6  북구청장 재활용쓰레기 처리 못 하는게 경영의 최고 전문가 인가 평가는 구민이 북구청...  복지환경국 자원순환과
# 7  북구청장 최고의 전문가 행정이 북구민에게 어디까지 미치나요 답변해 주셔요 북구청장북...          감사실
# 8  칠성초 횡단보도부근 및 침산동 일대 공사마무리를 서둘러주시기 바랍니다 침산동 국민은...      도시국 건설과
# 9  에어간판으로 인한 교통사고유발 민원을 넣었지만 해결되지 않았습니다 동일고충민원여부동...    도시국 도시행정과
#
#                                                after   after_dept
# 0  [매천동, 청구, 장미, 아파트, 삼우, 그린, 입구, 합리, 위치, 매천동, 청구...      도시국_건설과
# 1  [처리, 중, 언제, 어린이, 보호구역, 법주, 차, 불법, 신고, 지, 언제, 처...    도시국_도시행정과
# 2  [도로, 개설, 본인, 대구시, 북구, 태전동, 번지, 토지, 소유자, 상기, 토지...      도시국_건설과
# 3  [북, 구청장, 사실, 곳, 불법, 최고, 북구, 전문가, 북, 구청장, 사실, 곳...          감사실
# 4  [대구, 시장, 북, 구청장, 감, 사실, 부서, 폐쇄, 미관, 지구, 대구, 시장...          감사실
# 5  [북, 구청장, 주거, 환경, 정비, 해당, 주민, 반대, 전화, 문자, 카톡, 구...    도시국_건축주택과
# 6  [북, 구청장, 활용, 쓰레기, 처리, 게, 경영, 최고, 전문가, 평가, 구민, ...  복지환경국_자원순환과
# 7  [북, 구청장, 최고, 전문가, 행정, 북, 구민, 어디, 답변, 북구, 청장, 북...          감사실
# 8  [칠성, 초, 횡단보도, 부근, 침산동, 일대, 공사, 마무리, 침산동, 국민은행,...      도시국_건설과
# 9  [간판, 교통사고, 유발, 민원, 해결, 동일, 고충, 민원, 여부, 동일, 고충,...    도시국_도시행정과

# %%
# globals()['{}_{}'.format(name_list[0],complain_list[0]['after_dept'].unique()[0])]=[]

# %%
#각 지역+부서를 변수 이름으로 하는 리스트 만들기
my_list=[]
error_list=[]
for i in range(0,len(complain_list)):
  for j in range(0,len(complain_list[i]['after_dept'].unique())):
    try:
      globals()['{}_{}'.format(name_list[i],complain_list[i]['after_dept'].unique()[j])]=[]
      tmp_str='{}_{}'.format(name_list[i],complain_list[i]['after_dept'].unique()[j])
      my_list.append(tmp_str)
    except:
      error_list.append([i,j])
      continue

# %%
my_list
# Out:
# ['BukGu_도시국_건설과',
#  'BukGu_도시국_도시행정과',
#  'BukGu_감사실',
#  'BukGu_도시국_건축주택과',
#  'BukGu_복지환경국_자원순환과',
#  'BukGu_복지환경국_환경관리과',
#  'BukGu_도시국_교통과',
#  'BukGu_문화녹지국_공원녹지과',
#  'BukGu_읍/면/동사무소',
#  'BukGu_도시국_도시관리과',
#  'BukGu_주민생활지원국_환경관리과',
#  'BukGu_도시국_재난안전과',
#  'DalseongGun_건설도시국_건축과',
#  'DalseongGun_건설도시국_안전총괄과',
#  'DalseongGun_문화관광국_공원녹지과',
#  'DalseongGun_건설도시국_건설과',
#  'DalseongGun_경제환경국_교통과',
#  'DalseongGun_교육복지국_교육정책과',
#  'DalseongGun_경제환경국_환경과',
#  'DalseongGun_건설도시국_도시정비과',
#  'DalseongGun_읍/면/동사무소',
#  'DalseongGun_자치행정국_종합민원과',
#  'DalseongGun_경제환경국_청소위생과',
#  'DalseongGun_문화관광국_문화예술과',
#  'DalseongGun_경제환경국_농업정책과',
#  'DalseongGun_보건소_보건과',
#  'DalseongGun_건설도시국_도시계획과',
#  'DalseongGun_건설도시국_교통과',
#  'DalsuGu_도시창조국_공원녹지과',
#  'DalsuGu_경제환경국_청소과',
#  'DalsuGu_경제환경국_주차관리과',
#  'DalsuGu_경제환경국_교통행정과',
#  'DalsuGu_도시창조국_건설과',
#  'DalsuGu_도시창조국_건축과',
#  'DalsuGu_경제환경국_기후환경과',
#  'DalsuGu_읍/면/동사무소',
#  'DalsuGu_보건소_보건행정과',
#  'DalsuGu_경제환경국_환경보호과',
#  'DalsuGu_도시창조국_도시재생과',
#  'DalsuGu_복지문화국_문화체육관광과',
#  'DalsuGu_자치행정국_총무과',
#  'DalsuGu_경제환경국_일자리경제과',
#  'DalsuGu_경제환경국_녹색환경과',
#  'DalsuGu_도시건설국_도시관리과',
#  'DalsuGu_보건소_보건과',
#  'DongGu_도시안전국_건설과',
#  'DongGu_도시안전국_교통과',
#  'DongGu_도시안전국_건축주택과',
#  'DongGu_도시안전국_도시과',
#  'DongGu_도시안전국_공원녹지과',
#  'DongGu_경제복지국_경제지원과',
#  'DongGu_경제복지국_환경녹색과',
#  'DongGu_보건소_보건의약과',
#  'DongGu_읍/면/동사무소',
#  'DongGu_행정문화국_행정지원과',
#  'DongGu_복지생활국_환경자원과',
#  'DongGu_도시건설국_교통과',
#  'DongGu_복지생활국_경제과',
#  'DongGu_도시건설국_건설과',
#  'DongGu_도시건설국_도시디자인과',
#  'DongGu_도시건설국_건축주택과',
#  'DongGu_안전행정국_평생학습과',
#  'DongGu_도시건설국_안전녹지과',
#  'DongGu_주민생활지원국_환경청소과',
#  'DongGu_도시건설국_도시공원과',
#  'JungGu_도시안전국_건설과',
#  'JungGu_도시안전국_건축주택과',
#  'JungGu_도시안전국_교통과',
#  'JungGu_보건소_보건과',
#  'JungGu_관광경제국_환경자원과',
#  'JungGu_읍/면/동사무소',
#  'JungGu_관광경제국_문화교육과',
#  'JungGu_기획예산실',
#  'JungGu_환경건설국_교통과',
#  'JungGu_환경건설국_건축주택과',
#  'JungGu_도시재생국_도시재생과',
#  'JungGu_도시재생국_관광자원과',
#  'JungGu_환경건설국_녹색환경과',
#  'JungGu_환경건설국_건설안전과',
#  'JungGu_도시관광국_건축주택과',
#  'JungGu_행정지원국_경제과',
#  'JungGu_안전행정국_경제과',
#  'JungGu_도시관광국_건설과',
#  'JungGu_주민생활지원국_문화관광과',
#  'JungGu_도시국_도시관리과',
#  'JungGu_주민생활지원국_환경과',
#  'JungGu_총무국_총무과',
#  'NamGu_도시국_건설과',
#  'NamGu_도시국_도시행정과',
#  'NamGu_감사실',
#  'NamGu_도시국_건축주택과',
#  'NamGu_복지환경국_자원순환과',
#  'NamGu_복지환경국_환경관리과',
#  'NamGu_도시국_교통과',
#  'NamGu_문화녹지국_공원녹지과',
#  'NamGu_읍/면/동사무소',
#  'NamGu_도시국_도시관리과',
#  'NamGu_주민생활지원국_환경관리과',
#  'NamGu_도시국_재난안전과',
#  'SeoGu_읍/면/동사무소',
#  'SeoGu_보건소_보건행정과',
#  'SeoGu_도시안전국_건축주택과',
#  'SeoGu_도시안전국_교통과',
#  'SeoGu_도시안전국_도시공원과',
#  'SeoGu_복지생활국_환경청소과',
#  'SeoGu_도시안전국_도시재생과',
#  'SeoGu_자치행정국_문화홍보과',
#  'SeoGu_도시안전국_건설과',
#  'SeoGu_자치행정국_총무과',
#  'SeoGu_기획예산실',
#  'SeoGu_자치행정국_종합민원과',
#  'SeoGu_도시국_교통과',
#  'SeoGu_도시국_도시관리과',
#  'SeoGu_도시국_건설방재과',
#  'SeoGu_주민생활지원국_경제과',
#  'SeoGu_주민생활지원국_환경관리과',
#  'SeoGu_도시국_건축주택과',
#  'SeoGu_주민생활지원국_복지사업과',
#  'SeoGu_도시국_건설과',
#  'SeoGu_기획감사실',
#  'SeoGu_사회산업국_환경관리과',
#  'SeoGu_사회산업국_청소과',
#  'Suseonggu_도시국_건설과',
#  'Suseonggu_복지국_자원순환과',
#  'Suseonggu_도시국_교통과',
#  'Suseonggu_도시국_건축과',
#  'Suseonggu_복지국_녹색환경과',
#  'Suseonggu_도시국_공원녹지과',
#  'Suseonggu_읍/면/동사무소',
#  'Suseonggu_도시국_도시디자인과',
#  'Suseonggu_보건소_보건행정과',
#  'Suseonggu_복지국_경제환경과',
#  'Suseonggu_교육문화국_문화체육과',
#  'Suseonggu_복지국_복지과']

# %%
#각 과의 이름을 가진 리스트에 요소들 다 추가

for i in range(0,len(complain_list)):#각 구에 대해

  for j in range(0,len(complain_list[i]['after_dept'])):# 각 구의 데이터 프레임에 after_dept열에 대해

    for k in range(0,len(complain_list[i]['after'][j])):#각 구의 데이터 프레임에 after_dept열의 요소들에 대해
      if complain_list[i]['after'][j][k] in ['것','이것','저것','그것']:#한번 돌려봤는데 최빈값이 싹다 "것"이여서 제거
        continue
      else:
        (globals()['{}_{}'.format(name_list[i],complain_list[i]['after_dept'][j])]).append(complain_list[i]['after'][j][k])

# %%
BukGu_도시국_건설과
# Out:
# ['매천동',
#  '청구',
#  '장미',
#  '아파트',
#  '삼우',
#  '그린',
#  '입구',
#  '합리',
#  '위치',
#  '매천동',
#  '청구',
#  '장미',
#  '아파트',
#  '삼우',
#  '아파트',
#  '입구',
#  '매천',
#  '생활',
#  '용품',
#  '옆',
#  '진입로',
#  '내용',
#  '사람',
#  '이용',
#  '횡단',
#  '보도',
#  '아파트',
#  '차량',
#  '다님',
#  '새벽',
#  '매천',
#  '생활',
#  '용품',
#  '점',
#  '자동차',
#  '수리',
#  '점',
#  '문',
#  '시간',
#  '거리',
#  '보행자',
#  '우려',
#  '자동차',
#  '우측',
#  '사각지대',
#  '밤',
#  '거리',
#  '매천',
#  '생활',
#  '용품',
#  '점',
#  '자동차',
#  '수리',
#  '점',
#  '문',
#  '시간',
#  '거리',
#  '조명',
#  '시설',
#  '확인',
#  '후',
#  '조치',
#  '사진',
#  '첨부',
#  '도로',
#  '개설',
#  '본인',
#  '대구시',
#  '북구',
#  '태전동',
#  '번지',
#  '토지',
#  '소유자',
#  '상기',
#  '토지',
#  '농사',
#  '본인',
#  '외',
#  '필지',
#  '소유자',
#  '통행로',
#  '한정',
#  '범위',
#  '내',
#  '영농',
#  '수',
#  '밖',
#  '민법',
#  '제조',
#  '주위',
#  '토지',
#  '토지',
#  '건너',
#  '태전동',
#  '번지',
#  '국토',
#  '교통부',
#  '소유',
#  '도로',
#  '현황',
#  '농림',
#  '축산',
#  '부',
#  '소유',
#  '태전동',
#  '번지',
#  '구거',
#  '잠식',
#  '수풀',
#  '도로',
#  '역활',
#  '이',
#  '민원인',
#  '상기',
#  '번지',
#  '도로',
#  '개설',
#  '부탁',
#  '칠성',
#  '초',
#  '횡단보도',
#  '부근',
#  '침산동',
#  '일대',
#  '공사',
#  '마무리',
#  '침산동',
#  '국민은행',
#  '부근',
#  '하수관',
#  '공사',
#  '얼마',
#  '전',
#  '땅',
#  '관',
#  '공사',
#  '자체',
#  '아이',
#  '통행',
#  '위험',
#  '공사',
#  '관',
#  '뒤',
#  '마무리',
#  '천',
#  '상태',
#  '시간',
#  '천',
#  '고정',
#  '발',
#  '뻔',
#  '게',
#  '번',
#  '천위',
#  '고정',
#  '목적',
#  '보도',
#  '블럭',
#  '보도',
#  '블럭',
#  '애',
#  '발',
#  '십상',
#  '횡단보도',
#  '앞',
#  '위험',
#  '아이',
#  '신호',
#  '등불',
#  '경우',
#  '바닥상태',
#  '지경',
#  '사고',
#  '걱정',
#  '평소',
#  '횡단',
#  '보도',
#  '무시',
#  '우회전',
#  '차량',
#  '곳',
#  '아이',
#  '등',
#  '하교',
#  '길',
#  '걱정',
#  '때문',
#  '인도',
#  '통행',
#  '상태',
#  '가능',
#  '공사',
#  '마무리',
#  '수',
#  '신속',
#  '처리',
#  '부탁',
#  '공사',
#  '지연',
#  '수',
#  '상황',
#  '통행',
#  '불편',
#  '도로',
#  '정비',
#  '상태',
#  '어른',
#  '위험',
#  '팔달역',
#  '보행',
#  '데크',
#  '안녕',
#  '매천동',
#  '주민',
#  '청구',
#  '장미',
#  '삼우',
#  '그린',
#  '남쪽',
#  '팔달역',
#  '보행',
#  '데크',
#  '공사',
#  '중',
#  '공사',
#  '안내판',
#  '월일',
#  '공사',
#  '기간',
#  '공사',
#  '완료',
#  '공사',
#  '완료',
#  '시점',
#  '주민',
#  '언제',
#  '이용',
#  '가능',
#  '팔달동',
#  '구',
#  '탐',
#  '식당',
#  '자리',
#  '해수',
#  '업체',
#  '바닷물',
#  '방류',
#  '도로',
#  '파손',
#  '차량',
#  '충격',
#  '보행자',
#  '안전',
#  '위협',
#  '도로',
#  '보수',
#  '조치',
#  '청구',
#  '장미',
#  '남편',
#  '보도',
#  '교',
#  '공사',
#  '달째',
#  '진행',
#  '완공',
#  '시점',
#  '시간',
#  '공사',
#  '현장',
#  '방치',
#  '공사',
#  '펜스',
#  '바람',
#  '등',
#  '위험',
#  '팔',
#  '거천',
#  '주변',
#  '조경수',
#  '전지',
#  '시기',
#  '조절',
#  '당부',
#  '안녕',
#  '저',
#  '북구',
#  '동천동',
#  '주민',
#  '봄',
#  '팔',
#  '거천',
#  '주변',
#  '벚꽃',
#  '개나리',
#  '조팝나무',
#  '등',
#  '꽃',
#  '봄',
#  '점',
#  '글',
#  '개나리',
#  '조팝나무',
#  '봄',
#  '꽃',
#  '꽃',
#  '감상',
#  '후',
#  '봄',
#  '가지치기',
#  '늦여름',
#  '가을',
#  '가지치기',
#  '관계',
#  '봄',
#  '새순',
#  '전',
#  '꽃',
#  '가지',
#  '수',
#  '심정',
#  '주위',
#  '남천',
#  '가을',
#  '겨울',
#  '열매',
#  '잎',
#  '감상',
#  '수',
#  '이',
#  '가을',
#  '가지치기',
#  '관계',
#  '가지',
#  '일부',
#  '나무',
#  '형상',
#  '나무',
#  '중요',
#  '주민',
#  '자연',
#  '수',
#  '관리',
#  '중요',
#  '생각',
#  '전문가',
#  '의견',
#  '청취',
#  '관리',
#  '당부',
#  '도로',
#  '패',
#  '보수',
#  '필요',
#  '기입',
#  '주소',
#  '작년',
#  '월',
#  '입주',
#  '주민',
#  '첨부',
#  '사진',
#  '입주',
#  '전',
#  '수도관',
#  '공사',
#  '도로',
#  '정도',
#  '차',
#  '충격',
#  '부분',
#  '확인',
#  '보수',
#  '확인',
#  '지반',
#  '지반',
#  '바닥',
#  '무판',
#  '조치',
#  '중',
#  '하나',
#  '통행',
#  '위험',
#  '조치',
#  '연경동',
#  '연경',
#  '숲',
#  '옆',
#  '개울',
#  '악취',
#  '물',
#  '한동안',
#  '날씨',
#  '온도',
#  '동네',
#  '악취',
#  '때문',
#  '산책',
#  '원인',
#  '개울물',
#  '물',
#  '색깔',
#  '혼탁',
#  '거품',
#  '악취',
#  '발생',
#  '상황',
#  '원인',
#  '파악',
#  '화천',
#  '모기',
#  '이름',
#  '날벌레',
#  '물',
#  '때문',
#  '확인',
#  '부탁',
#  '매천동',
#  '청구',
#  '장미',
#  '부근',
#  '공사',
#  '안녕',
#  '불철주야',
#  '북구',
#  '발전',
#  '공무원',
#  '감사',
#  '인사',
#  '저희',
#  '동네',
#  '진행',
#  '중',
#  '공사',
#  '관련',
#  '문의',
#  '가지',
#  '제안',
#  '청구',
#  '장미',
#  '남쪽',
#  '보도',
#  '교',
#  '공사',
#  '완공',
#  '이용',
#  '가능',
#  '지요',
#  '해당',
#  '교량',
#  '년',
#  '초반',
#  '이야기',
#  '공사',
#  '중',
#  '년',
#  '말',
#  '공사',
#  '시작',
#  '당시',
#  '년',
#  '월',
#  '완공',
#  '목표',
#  '교량',
#  '상판',
#  '등',
#  '공사',
#  '진도',
#  '게',
#  '이용',
#  '날림',
#  '공사',
#  '이야기',
#  '년',
#  '이상',
#  '교량',
#  '그',
#  '차량',
#  '이용',
#  '보도',
#  '교로',
#  '추진',
#  '상황',
#  '공사',
#  '지연',
#  '주민',
#  '때',
#  '봄',
#  '이용',
#  '가능',
#  '언제',
#  '완공',
#  '예정',
#  '팔달역',
#  '보행',
#  '데크',
#  '최근',
#  '공사',
#  '올해',
#  '초',
#  '말',
#  '보도',
#  '교',
#  '근처',
#  '팔달역',
#  '쪽',
#  '보행',
#  '데크',
#  '공사',
#  '시공',
#  '중',
#  '월',
#  '초',
#  '중순',
#  '한참',
#  '공사',
#  '설',
#  '연휴',
#  '이후',
#  '공사',
#  '진행',
#  '이유',
#  '중단',
#  '애초',
#  '계획',
#  '월',
#  '이용',
#  '가능',
#  '삼우',
#  '그린',
#  '팔달역',
#  '쪽',
#  '길',
#  '대형',
#  '차량',
#  '해수',
#  '곳',
#  '길',
#  '불법',
#  '소금물',
#  '막',
#  '거리',
#  '날',
#  '길',
#  '아스팔트',
#  '소금물',
#  '부식',
#  '공사',
#  '지연',
#  '완공',
#  '청구',
#  '장미',
#  '옆',
#  '운동',
#  '시설',
#  '정자',
#  '운동',
#  '기구',
#  '정자',
#  '설치',
#  '점',
#  '감사',
#  '운동',
#  '기구',
#  '유용',
#  '사용',
#  '여기',
#  '가지',
#  '정자',
#  '육안',
#  '공사',
#  '완료',
#  '언제',
#  '사람',
#  '이용',
#  '가능',
#  '운동',
#  '기구',
#  '이용',
#  '구민',
#  '건너편',
#  '산책로',
#  '연결',
#  '돌다리',
#  '게',
#  '듯',
#  '한데',
#  '설치',
#  '예정',
#  '가로등',
#  '개선',
#  '삼우',
#  '그린',
#  '정문',
#  '앞',
#  '가로등',
#  '불빛',
#  '감',
#  '삼우',
#  '그린',
#  '팔달역',
#  '쪽',
#  '길',
#  '가로등',
#  '수',
#  '청구',
#  '장미',
#  '뒤편',
#  '북부',
#  '화물',
#  '터미널',
#  '부지',
#  '매천',
#  '시장',
#  '역',
#  '이용',
#  '주변',
#  '상가',
#  '매천',
#  '고등학교',
#  '통학',
#  '사람',
#  '밤',
#  '터미널',
#  '자리',
#  '위험',
#  '팔',
#  '거천',
#  '자전거',
#  '도로',
#  '안전시설',
#  '충건',
#  '팔',
#  '거천',
#  '자전거',
#  '도로',
#  '안전시설',
#  '확충',
#  '자전거',
#  '도로',
#  '인도',
#  '분',
#  '계도',
#  '부탁',
#  '태',
#  '전교',
#  '교각',
#  '아래',
#  '자전거',
#  '도로',
#  '도',
#  '이상',
#  '사고',
#  '위험',
#  '인도',
#  '사람',
#  '도로',
#  '구조',
#  '코너',
#  '자전거',
#  '시야',
#  '확보',
#  '데',
#  '만약',
#  '사람',
#  '사고',
#  '수',
#  '자전거',
#  '중',
#  '차선',
#  '역방향',
#  '분',
#  '위험',
#  '인도',
#  '강변',
#  '쪽',
#  '안전',
#  '거울',
#  '설치',
#  '계도',
#  '부탁',
#  '금호강',
#  '자전거',
#  '도로',
#  '이용',
#  '사람',
#  '왕래',
#  '곳',
#  '위험',
#  '구간',
#  '자전거',
#  '도로',
#  '인도',
#  '선',
#  '구분',
#  '게',
#  '중앙',
#  '분리',
#  '봉',
#  '화단',
#  '구분',
#  '선',
#  '곳',
#  '자전거',
#  '도로',
#  '보행자',
#  '팔',
#  '거천',
#  '금호강',
#  '자전거',
#  '일반',
#  '사람',
#  '교행',
#  '데',
#  '시설물',
#  '일부분',
#  '산상',
#  '어려움',
#  '특정',
#  '구',
#  '간태',
#  '암',
#  '교',
#  '홈플러스',
#  '만',
#  '안전시설',
#  '확충',
#  '자전거',
#  '도로',
#  '인도',
#  '구분',
#  '계도',
#  '부탁',
#  '옆',
#  '인도',
#  '자전거',
#  '도로',
#  '생각',
#  '보행자',
#  '런닝',
#  '분',
#  '중',
#  '양쪽',
#  '귀',
#  '이어폰',
#  '분',
#  '뒤',
#  '위험',
#  '신호',
#  '경우',
#  '강아지',
#  '산책',
#  '시',
#  '목줄',
#  '이상',
#  '자전거',
#  '도로',
#  '인접',
#  '자전거',
#  '도로',
#  '자전거',
#  '때',
#  '강아지',
#  '사고',
#  '뻔',
#  '적',
#  '번',
#  '날',
#  '전',
#  '지금',
#  '위험',
#  '경우',
#  '발생',
#  '데',
#  '날',
#  '주말',
#  '자전거',
#  '정상',
#  '가능',
#  '안전시설',
#  '확충',
#  '지속',
#  '계도',
#  '부탁',
#  '밤중',
#  '공사',
#  '때문',
#  '잠',
#  '현재',
#  '몇일',
#  '밤',
#  '새벽',
#  '시',
#  '시',
#  '시',
#  '시',
#  '시',
#  '시',
#  '잠',
#  '낮',
#  '소음',
#  '소리',
#  '소리',
#  '천둥',
#  '번개',
#  '소리',
#  '녹음',
#  '정돕니다',
#  '유통단지',
#  '땅',
#  '유통단지',
#  '인근',
#  '인도',
#  '땅',
#  '번',
#  '민원',
#  '까지',
#  '답변',
#  '처리',
#  '사무실',
#  '앞',
#  '인도',
#  '시간',
#  '아래',
#  '아래',
#  '이',
#  '불편',
#  '불안감',
#  '조치',
#  '안내',
#  '표지판',
#  '오기재',
#  '신고',
#  '동호',
#  '차량기지',
#  '칠곡',
#  '차량기지',
#  '명칭',
#  '변경',
#  '수고',
#  '칠곡경대병원역',
#  '칠곡',
#  '차량기지',
#  '방향',
#  '지하',
#  '통로',
#  '진입',
#  '전',
#  '칠',
#  '곡',
#  '차량기지',
#  '방향',
#  '안내',
#  '표지판',
#  '설치',
#  '명칭',
#  '칠곡',
#  '차량기지',
#  '동호',
#  '차량기지',
#  '오기재',
#  '차량기지',
#  '민원인',
#  '혼돈',
#  '설치',
#  '곳',
#  '어딘지',
#  '군데',
#  '확인',
#  '수',
#  '여기',
#  '글',
#  '북',
#  '구청',
#  '설치',
#  '설치',
#  '곳',
#  '이첩',
#  '부탁',
#  '북',
#  '구청',
#  '설치',
#  '오기재',
#  '감사',
#  '금호지구',
#  '주변',
#  '제설',
#  '작업',
#  '미비',
#  '눈',
#  '브라운스톤',
#  '강북',
#  '아파트',
#  '앞',
#  '도로',
#  '와룡',
#  '대교',
#  '서재',
#  '도로는',
#  '제설',
#  '작업',
#  '와룡',
#  '대교',
#  '서재',
#  '도로는',
#  '눈',
#  '위험',
#  '서재',
#  '시내',
#  '계대',
#  '길',
#  '제설',
#  '작업',
#  '도로',
#  '상태',
#  '세금',
#  '금호지구',
#  '주변',
#  '도로',
#  '제설',
#  '작업',
#  '답변',
#  '이전',
#  '해',
#  '눈',
#  '때',
#  '마찬가지',
#  '상황',
#  '계대',
#  '쪽',
#  '출퇴근',
#  '차량',
#  '저',
#  '걸로',
#  '시정',
#  '여름',
#  '민원',
#  '금호지구',
#  '내',
#  '공원',
#  '상가',
#  '주변',
#  '인도',
#  '보도',
#  '블럭',
#  '잡초',
#  '관리',
#  '곳',
#  '분',
#  '여기',
#  '촌',
#  '화',
#  '금호지구',
#  '공원',
#  '관리',
#  '정기',
#  '계획',
#  '일정',
#  '등',
#  '답변',
#  '칠',
#  '곡',
#  '운암',
#  '태전',
#  '간',
#  '강변도로',
#  '새벽',
#  '시간',
#  '보안등',
#  '작동',
#  '여부',
#  '지난주',
#  '상기',
#  '구간',
#  '새벽',
#  '시',
#  '운동',
#  '보안등',
#  '운동',
#  '동일',
#  '시간',
#  '시',
#  '그때',
#  '보안등',
#  '산책',
#  '주민',
#  '핸드폰',
#  '모습',
#  '점',
#  '등',
#  '문제',
#  '건지',
#  '확인',
#  '주민',
#  '안전',
#  '직결',
#  '부분',
#  '이상',
#  '조치',
#  ...]

# %%
from collections import Counter
#최빈값을 10개까지!
counter = Counter(BukGu_도시국_건설과)
most_common = counter.most_common()

# %%
most_common[:10]
# Out:
# [('도로', 1197),
#  ('수', 1123),
#  ('건설', 966),
#  ('민원', 875),
#  ('분할', 800),
#  ('답변', 740),
#  ('공사', 726),
#  ('설치', 697),
#  ('당시', 641),
#  ('인도', 583)]

# %%
#각 구별 부서 리스트의 값을 최빈값 10개로 바꾸자!
for i in range(0,len(my_list)):
  counter = Counter(globals()['{}'.format(my_list[i])])
  most_common = counter.most_common()
  globals()['{}'.format(my_list[i])]=most_common[:10]

# %%
#이렇게 바뀜
for i in range(0,len(my_list)):
  print (globals()['{}'.format(my_list[i])])
# Out:
# [('도로', 1197), ('수', 1123), ('건설', 966), ('민원', 875), ('분할', 800), ('답변', 740), ('공사', 726), ('설치', 697), ('당시', 641), ('인도', 583)]
# [('불법', 108), ('단속', 97), ('민원', 97), ('물', 80), ('광고', 72), ('북구', 63), ('시장', 57), ('인도', 55), ('앞', 52), ('노점', 51)]
# [('불법', 6189), ('시장', 4369), ('건축', 4052), ('북', 3996), ('행정', 3920), ('구민', 3564), ('구청장', 3173), ('북구', 2863), ('대구', 2806), ('허가', 2656)]
# [('수', 1784), ('시설', 1763), ('제조', 1753), ('건축', 1738), ('아파트', 1493), ('제호', 1478), ('등', 1437), ('지역', 1259), ('건축물', 1232), ('별표', 1152)]
# [('쓰레기', 817), ('분리수거', 185), ('행정', 182), ('수거', 172), ('처리', 169), ('활용', 168), ('북구', 167), ('민원', 164), ('투기', 155), ('수', 144)]
# [('소음', 478), ('공사', 467), ('쓰레기', 454), ('수', 269), ('민원', 247), ('주민', 230), ('아파트', 182), ('현장', 176), ('집', 166), ('북구', 161)]
# [('주차', 3408), ('단속', 2172), ('차량', 1774), ('차', 1628), ('불법', 1253), ('도로', 1156), ('수', 841), ('앞', 799), ('민원', 632), ('아파트', 609)]
# [('공원', 285), ('나무', 131), ('수', 106), ('설치', 99), ('북구', 94), ('주민', 91), ('공사', 89), ('불편', 88), ('가로수', 86), ('앞', 83)]
# [('주민', 215), ('일', 137), ('직원', 130), ('센터', 127), ('사람', 125), ('말', 115), ('수', 111), ('제', 103), ('동사무소', 97), ('저', 93)]
# [('공원', 442), ('수', 275), ('현수막', 224), ('나무', 222), ('주민', 212), ('북구', 203), ('가로수', 186), ('등', 176), ('사람', 166), ('일', 158)]
# [('쓰레기', 786), ('수', 379), ('소음', 339), ('음식물', 333), ('집', 304), ('주민', 261), ('공사', 250), ('앞', 249), ('일', 238), ('수거', 230)]
# [('불법', 519), ('단속', 504), ('노점상', 468), ('시장', 298), ('노점', 228), ('사람', 225), ('장사', 219), ('동변동', 211), ('일', 200), ('인도', 190)]
# [('아파트', 1023), ('입주민', 655), ('주차', 601), ('분양', 578), ('수', 547), ('하나', 510), ('달성', 504), ('삼정', 498), ('건설', 483), ('군청', 473)]
# [('수', 127), ('천', 93), ('공사', 82), ('달성군', 76), ('설치', 73), ('확진', 71), ('주민', 66), ('차량', 66), ('사업', 62), ('통행', 58)]
# [('공원', 249), ('수', 143), ('설치', 97), ('길', 89), ('사람', 81), ('등', 80), ('민원', 79), ('곳', 70), ('주민', 66), ('쪽', 62)]
# [('도로', 672), ('멜', 502), ('스노우', 460), ('설치', 455), ('협성', 453), ('포레', 374), ('휴', 345), ('아파트', 322), ('길', 322), ('수', 288)]
# [('주차', 523), ('설치', 485), ('단속', 470), ('길', 458), ('불법', 457), ('차', 448), ('차량', 399), ('아이', 379), ('주정차', 367), ('스쿨', 367)]
# [('어린이집', 101), ('아이', 94), ('수', 54), ('증원', 42), ('구지', 40), ('도원', 39), ('보육', 28), ('곳', 27), ('입소', 27), ('일', 21)]
# [('공사', 319), ('소음', 312), ('공장', 148), ('민원', 135), ('제지', 134), ('수', 130), ('주민', 126), ('냄새', 122), ('아파트', 110), ('소리', 104)]
# [('가로등', 95), ('설치', 87), ('민원', 63), ('길', 62), ('도로', 53), ('수', 43), ('공사', 41), ('요청', 32), ('주민', 30), ('쪽', 29)]
# [('쓰레기', 119), ('민원', 104), ('수', 95), ('일', 89), ('주민', 85), ('살장', 82), ('등', 75), ('설치', 72), ('요청', 63), ('장', 63)]
# [('공사', 38), ('민원', 33), ('에너지', 28), ('허가', 26), ('건물', 22), ('저', 19), ('생각', 18), ('설치', 16), ('도시', 16), ('건축', 15)]
# [('쓰레기', 75), ('민원', 46), ('수거', 45), ('활용', 45), ('냄새', 44), ('수', 43), ('공장', 36), ('음식물', 32), ('시간', 31), ('사람', 31)]
# [('달성', 83), ('수', 68), ('파크', 56), ('달성군', 54), ('시설', 46), ('문화', 45), ('군민', 42), ('이용', 38), ('년', 36), ('골프장', 36)]
# [('수', 68), ('견', 45), ('개', 41), ('강아지', 40), ('아파트', 36), ('고양이', 34), ('사람', 32), ('민원', 32), ('달성군', 31), ('동물', 31)]
# [('보건소', 110), ('달성군', 76), ('검사', 46), ('수', 44), ('전화', 41), ('일', 38), ('코로나', 37), ('격리', 31), ('병원', 29), ('저', 27)]
# [('도로', 54), ('민원', 51), ('가로등', 51), ('공사', 45), ('설치', 42), ('길', 37), ('불법', 32), ('달성군', 29), ('등', 28), ('아파트', 26)]
# [('차량', 156), ('주차', 151), ('도로', 137), ('차', 127), ('단속', 111), ('불법', 104), ('민원', 93), ('수', 92), ('버스', 82), ('주정차', 82)]
# [('공원', 893), ('수', 271), ('설치', 232), ('주민', 205), ('아이', 195), ('민원', 194), ('사람', 164), ('부탁', 157), ('나무', 153), ('이용', 151)]
# [('쓰레기', 1276), ('수거', 635), ('음식물', 349), ('앞', 317), ('집', 284), ('수', 272), ('처리', 237), ('활용', 237), ('투기', 235), ('불법', 233)]
# [('주차', 3479), ('단속', 2528), ('차량', 2026), ('불법', 1737), ('차', 1711), ('도로', 1231), ('앞', 951), ('주정차', 844), ('수', 735), ('민원', 712)]
# [('차량', 193), ('주차', 186), ('설치', 174), ('도로', 126), ('차', 106), ('민원', 84), ('앞', 82), ('불법', 75), ('수', 68), ('단속', 61)]
# [('도로', 592), ('공사', 470), ('인도', 376), ('길', 325), ('수', 298), ('설치', 291), ('앞', 270), ('가로등', 240), ('차량', 222), ('주민', 221)]
# [('아파트', 719), ('공사', 711), ('수', 544), ('관리', 374), ('민원', 367), ('구청', 362), ('건축', 347), ('등', 326), ('일', 290), ('집', 289)]
# [('공사', 143), ('소음', 134), ('민원', 73), ('아파트', 44), ('소리', 43), ('주말', 39), ('거', 37), ('주민', 35), ('수', 34), ('현장', 34)]
# [('주민', 269), ('센터', 187), ('수', 171), ('일', 167), ('직원', 128), ('사람', 125), ('마스크', 120), ('말', 114), ('제', 113), ('민원', 103)]
# [('방역', 105), ('바퀴벌레', 85), ('모기', 66), ('수', 61), ('병원', 46), ('거', 44), ('코로나', 44), ('부탁', 36), ('확진', 36), ('검사', 35)]
# [('공사', 510), ('소음', 495), ('수', 194), ('현장', 156), ('민원', 147), ('소리', 140), ('시', 133), ('때문', 132), ('아파트', 130), ('냄새', 124)]
# [('불법', 116), ('도로', 115), ('앞', 107), ('수', 100), ('인도', 92), ('단속', 85), ('주차', 82), ('사람', 78), ('민원', 73), ('불편', 63)]
# [('수', 98), ('구청', 83), ('수영장', 67), ('일', 61), ('생각', 61), ('사람', 60), ('달서', 55), ('민원', 55), ('조형물', 55), ('센터', 54)]
# [('업무', 155), ('정규직', 88), ('구청', 85), ('지속', 80), ('일', 76), ('답변', 75), ('주민', 72), ('수', 72), ('공개', 71), ('정보', 69)]
# [('수', 102), ('시장', 86), ('개', 78), ('고양이', 72), ('사람', 67), ('일', 65), ('구청', 62), ('저', 51), ('민원', 45), ('문제', 42)]
# [('소음', 473), ('공사', 442), ('수', 221), ('냄새', 176), ('소리', 162), ('주민', 150), ('아파트', 146), ('민원', 138), ('시', 136), ('집', 124)]
# [('공원', 591), ('수', 338), ('앞', 249), ('주민', 239), ('사람', 237), ('구청', 227), ('단속', 222), ('설치', 220), ('불법', 202), ('도로', 186)]
# [('장례식장', 357), ('주민', 325), ('병원', 321), ('말', 179), ('사람', 172), ('수', 163), ('구청', 163), ('보건소', 145), ('우리', 127), ('생각', 113)]
# [('도로', 240), ('민원', 147), ('수', 144), ('공사', 143), ('길', 142), ('설치', 137), ('동구', 131), ('앞', 128), ('인도', 111), ('주민', 110)]
# [('주차', 1031), ('단속', 561), ('차량', 526), ('차', 434), ('불법', 344), ('도로', 324), ('수', 275), ('주정차', 270), ('설치', 262), ('앞', 250)]
# [('아파트', 736), ('수', 734), ('공사', 639), ('세대', 574), ('입주', 571), ('아이', 510), ('등', 503), ('안전', 460), ('학교', 381), ('동대구', 357)]
# [('현수막', 95), ('불법', 65), ('앞', 45), ('수', 42), ('민원', 40), ('요청', 39), ('설치', 39), ('도로', 37), ('동구', 34), ('철거', 34)]
# [('공원', 205), ('주민', 113), ('설치', 103), ('수', 90), ('내', 84), ('가로수', 74), ('동구', 73), ('이용', 70), ('민원', 69), ('길', 56)]
# [('개', 83), ('민원', 60), ('수', 57), ('일', 47), ('동구', 40), ('도시', 38), ('사람', 36), ('길', 36), ('마리', 34), ('구청', 31)]
# [('소음', 344), ('쓰레기', 322), ('공사', 311), ('수거', 254), ('집', 169), ('주민', 165), ('수', 158), ('앞', 157), ('민원', 149), ('일', 124)]
# [('보건소', 114), ('동구', 96), ('방역', 92), ('모기', 67), ('수', 67), ('일', 67), ('전화', 64), ('격리', 58), ('부탁', 40), ('코로나', 39)]
# [('주민', 134), ('일', 130), ('센터', 98), ('저', 94), ('사람', 93), ('제', 92), ('수', 87), ('말', 79), ('동사무소', 78), ('직원', 77)]
# [('설치', 96), ('가로등', 87), ('주민', 80), ('수', 45), ('집', 44), ('동구', 39), ('골목', 35), ('센터', 30), ('일', 29), ('에너지', 29)]
# [('쓰레기', 249), ('소음', 165), ('수거', 130), ('수', 98), ('동구', 98), ('민원', 83), ('주민', 80), ('음식물', 79), ('시', 78), ('공사', 78)]
# [('주차', 1401), ('단속', 901), ('차량', 858), ('차', 740), ('도로', 610), ('불법', 482), ('앞', 433), ('수', 432), ('동구', 338), ('차선', 295)]
# [('개', 68), ('수', 65), ('동구', 58), ('일', 51), ('시장', 51), ('사람', 48), ('생각', 44), ('구청', 42), ('저', 40), ('집', 37)]
# [('도로', 559), ('앞', 363), ('공사', 362), ('수', 330), ('가로등', 312), ('길', 292), ('설치', 291), ('인도', 260), ('사람', 257), ('동구', 253)]
# [('불법', 84), ('단속', 75), ('현수막', 60), ('도로', 46), ('구청', 35), ('민원', 35), ('설치', 35), ('조치', 34), ('물', 34), ('철거', 33)]
# [('아파트', 901), ('공사', 617), ('수', 549), ('동구', 535), ('주민', 525), ('승인', 404), ('입주', 362), ('분양', 350), ('일', 338), ('건물', 331)]
# [('동구', 113), ('수', 86), ('도서관', 72), ('이용', 46), ('시설', 41), ('생각', 40), ('설치', 37), ('저', 37), ('운동', 35), ('관광', 35)]
# [('공원', 180), ('수', 95), ('주민', 90), ('아이', 88), ('놀이터', 76), ('동구', 74), ('사람', 65), ('신평동', 65), ('설치', 64), ('길', 58)]
# [('쓰레기', 489), ('음식물', 294), ('수', 229), ('소음', 204), ('수거', 203), ('집', 200), ('사람', 185), ('주민', 168), ('앞', 165), ('일', 160)]
# [('공원', 178), ('수', 101), ('주민', 85), ('설치', 82), ('운동', 79), ('사람', 74), ('가로수', 74), ('앞', 68), ('동구', 67), ('생각', 60)]
# [('공사', 39), ('수', 30), ('민원', 30), ('도로', 29), ('앞', 28), ('중구', 23), ('조치', 22), ('등', 20), ('길', 19), ('건물', 19)]
# [('조합', 1057), ('조합원', 845), ('아파트', 821), ('수', 774), ('공개', 742), ('중구', 629), ('입주', 571), ('더샵', 552), ('대봉', 546), ('등', 541)]
# [('주차', 373), ('단속', 186), ('차량', 137), ('차', 128), ('불법', 93), ('수', 92), ('주정차', 84), ('민원', 83), ('도로', 80), ('설치', 71)]
# [('방역', 55), ('모기', 49), ('중구', 46), ('민원', 39), ('수', 31), ('보건소', 31), ('병원', 30), ('중', 29), ('사람', 26), ('일', 24)]
# [('소음', 47), ('공사', 29), ('사람', 23), ('민원', 20), ('새벽', 20), ('시', 17), ('쓰레기', 16), ('때문', 15), ('집', 15), ('앞', 14)]
# [('주민', 79), ('사람', 54), ('일', 45), ('센터', 44), ('발급', 41), ('직원', 39), ('말', 36), ('제', 34), ('저', 34), ('서류', 33)]
# [('청라', 300), ('중구', 274), ('체육', 211), ('센터', 203), ('명칭', 172), ('국민', 141), ('이름', 104), ('지역', 101), ('확정', 90), ('대표', 81)]
# [('중구', 83), ('민원', 82), ('청장', 52), ('전화', 45), ('청', 45), ('일', 40), ('구청', 38), ('답변', 34), ('통화', 34), ('지명', 34)]
# [('주차', 1371), ('단속', 996), ('차', 684), ('차량', 638), ('불법', 390), ('사람', 335), ('수', 313), ('일', 311), ('앞', 307), ('도로', 294)]
# [('공사', 104), ('민원', 58), ('소음', 57), ('현장', 41), ('수', 34), ('시', 29), ('아파트', 29), ('남산', 28), ('개발', 28), ('문', 26)]
# [('가로수', 42), ('민원', 36), ('사람', 34), ('앞', 33), ('광고', 32), ('중', 32), ('중구', 31), ('불법', 30), ('물', 29), ('공사', 28)]
# [('년', 57), ('김광석', 53), ('길', 52), ('내용', 52), ('수정', 47), ('골목', 43), ('오류', 40), ('부분', 40), ('중', 39), ('수', 39)]
# [('쓰레기', 213), ('수', 89), ('공사', 86), ('소음', 80), ('수거', 73), ('중', 72), ('일', 59), ('중구', 55), ('앞', 53), ('민원', 49)]
# [('도로', 36), ('민원', 27), ('앞', 26), ('곳', 22), ('공사', 22), ('수', 22), ('설치', 20), ('골목길', 20), ('길', 20), ('일', 19)]
# [('중구', 909), ('입주', 812), ('수', 666), ('아파트', 654), ('중', 591), ('승인', 561), ('해링턴', 552), ('구청', 524), ('공사', 501), ('플레이스', 499)]
# [('일', 88), ('중구', 76), ('수', 73), ('시장', 65), ('말', 56), ('원', 56), ('분', 50), ('중', 49), ('구청', 49), ('년', 46)]
# [('중구', 492), ('마트', 387), ('시장', 360), ('입점', 293), ('대형', 268), ('청', 180), ('중', 147), ('홈플러스', 146), ('답변', 125), ('수', 120)]
# [('공사', 227), ('도로', 140), ('앞', 111), ('민원', 85), ('수', 79), ('일', 72), ('번', 67), ('골목', 66), ('인도', 64), ('구청', 63)]
# [('수', 52), ('대구', 49), ('청소년', 36), ('중구', 34), ('생각', 33), ('저', 32), ('일', 30), ('중', 30), ('골목', 29), ('사람', 25)]
# [('사람', 64), ('중구', 55), ('수', 52), ('거리', 52), ('대구', 49), ('앞', 48), ('가로수', 41), ('인도', 38), ('나무', 38), ('도로', 36)]
# [('쓰레기', 187), ('사람', 73), ('소음', 66), ('음식물', 66), ('수', 65), ('일', 58), ('공사', 51), ('집', 49), ('중구', 48), ('처리', 48)]
# [('주차', 114), ('단속', 106), ('차량', 81), ('일', 59), ('차', 57), ('제', 57), ('저', 56), ('수', 55), ('견인', 54), ('스티커', 48)]
# [('도로', 1197), ('수', 1123), ('건설', 966), ('민원', 875), ('분할', 800), ('답변', 740), ('공사', 726), ('설치', 697), ('당시', 641), ('인도', 583)]
# [('불법', 108), ('단속', 97), ('민원', 97), ('물', 80), ('광고', 72), ('북구', 63), ('시장', 57), ('인도', 55), ('앞', 52), ('노점', 51)]
# [('불법', 6178), ('시장', 4368), ('건축', 4045), ('북', 3992), ('행정', 3914), ('구민', 3561), ('구청장', 3172), ('북구', 2859), ('대구', 2802), ('허가', 2653)]
# [('수', 1784), ('시설', 1763), ('제조', 1753), ('건축', 1738), ('아파트', 1493), ('제호', 1478), ('등', 1437), ('지역', 1259), ('건축물', 1232), ('별표', 1152)]
# [('쓰레기', 817), ('분리수거', 185), ('행정', 182), ('수거', 172), ('처리', 169), ('활용', 168), ('북구', 167), ('민원', 164), ('투기', 155), ('수', 144)]
# [('소음', 478), ('공사', 467), ('쓰레기', 454), ('수', 269), ('민원', 247), ('주민', 230), ('아파트', 182), ('현장', 176), ('집', 166), ('북구', 161)]
# [('주차', 3408), ('단속', 2172), ('차량', 1774), ('차', 1628), ('불법', 1253), ('도로', 1156), ('수', 841), ('앞', 799), ('민원', 632), ('아파트', 609)]
# [('공원', 285), ('나무', 131), ('수', 106), ('설치', 99), ('북구', 94), ('주민', 91), ('공사', 89), ('불편', 88), ('가로수', 86), ('앞', 83)]
# [('주민', 215), ('일', 137), ('직원', 130), ('센터', 127), ('사람', 125), ('말', 115), ('수', 111), ('제', 103), ('동사무소', 97), ('저', 93)]
# [('공원', 442), ('수', 275), ('현수막', 224), ('나무', 222), ('주민', 212), ('북구', 203), ('가로수', 186), ('등', 176), ('사람', 166), ('일', 158)]
# [('쓰레기', 786), ('수', 379), ('소음', 339), ('음식물', 333), ('집', 304), ('주민', 261), ('공사', 250), ('앞', 249), ('일', 238), ('수거', 230)]
# [('불법', 519), ('단속', 504), ('노점상', 468), ('시장', 298), ('노점', 228), ('사람', 225), ('장사', 219), ('동변동', 211), ('일', 200), ('인도', 190)]
# [('주차', 110), ('주민', 88), ('통장', 75), ('수', 72), ('사람', 64), ('불법', 64), ('일', 62), ('집', 61), ('앞', 56), ('분', 51)]
# [('모기', 38), ('방역', 33), ('일', 24), ('냄새', 22), ('집', 21), ('격리', 17), ('서구', 16), ('보건소', 15), ('수', 14), ('부탁', 14)]
# [('소음', 266), ('층간', 248), ('수', 247), ('년', 233), ('아파트', 213), ('민원', 212), ('답변', 207), ('서구', 193), ('공사', 188), ('문제', 186)]
# [('주차', 396), ('차', 199), ('차량', 166), ('단속', 142), ('앞', 117), ('도로', 114), ('불법', 101), ('서구', 93), ('민원', 83), ('설치', 82)]
# [('공원', 151), ('길', 59), ('나무', 59), ('수', 57), ('민원', 48), ('도시', 44), ('사람', 43), ('철거', 43), ('주민', 41), ('서구', 40)]
# [('쓰레기', 291), ('수거', 169), ('수', 164), ('민원', 145), ('서구', 130), ('악취', 126), ('집', 112), ('냄새', 106), ('주민', 106), ('앞', 100)]
# [('서구', 110), ('전신주', 75), ('민원', 73), ('수', 71), ('지중화', 58), ('불법', 51), ('등', 50), ('주차', 44), ('답변', 43), ('사람', 42)]
# [('서구', 63), ('수', 35), ('설치', 35), ('주민', 31), ('공원', 27), ('구청', 24), ('글', 24), ('시간', 23), ('민원', 22), ('년', 22)]
# [('가로등', 110), ('길', 80), ('골목', 77), ('도로', 71), ('민원', 64), ('집', 52), ('공사', 49), ('앞', 47), ('서구', 44), ('설치', 42)]
# [('서구', 90), ('설치', 69), ('일', 63), ('집', 60), ('주민', 57), ('수', 56), ('사람', 51), ('직원', 49), ('생각', 46), ('구청', 43)]
# [('서구', 109), ('민원', 58), ('공무원', 37), ('수', 23), ('청', 23), ('도서관', 23), ('대구', 21), ('주민', 21), ('고충', 21), ('업무', 20)]
# [('여권', 48), ('사진', 45), ('민원', 43), ('구청', 40), ('일', 38), ('규정', 32), ('수', 30), ('민원인', 29), ('레미콘', 29), ('등', 26)]
# [('주차', 1056), ('단속', 641), ('차', 550), ('차량', 456), ('수', 298), ('도로', 284), ('불법', 273), ('앞', 247), ('일', 226), ('견인', 199)]
# [('공원', 153), ('가로등', 150), ('주차', 133), ('앞', 130), ('수', 122), ('사람', 114), ('집', 107), ('부탁', 96), ('설치', 89), ('주민', 86)]
# [('공사', 102), ('도로', 97), ('골목', 94), ('수', 75), ('앞', 74), ('블럭', 68), ('인도', 67), ('자전거', 67), ('길', 63), ('차', 61)]
# [('오픈', 162), ('수', 156), ('서구', 155), ('이마트', 152), ('일', 150), ('구청', 107), ('사람', 107), ('산점', 106), ('도시', 89), ('답변', 85)]
# [('쓰레기', 429), ('집', 180), ('수', 177), ('냄새', 174), ('사람', 168), ('수거', 159), ('주민', 147), ('일', 141), ('서구', 135), ('민원', 133)]
# [('구청', 182), ('수', 152), ('집', 143), ('민원', 133), ('년', 132), ('서구', 131), ('주민', 130), ('일', 123), ('공사', 123), ('사람', 93)]
# [('서구', 60), ('수', 58), ('일', 53), ('저', 45), ('시간', 42), ('생각', 41), ('제', 34), ('말', 32), ('복지', 30), ('전화', 28)]
# [('도로', 38), ('공사', 34), ('집', 25), ('땅', 22), ('앞', 17), ('차량', 16), ('인도', 15), ('시', 15), ('수', 15), ('평리동', 13)]
# [('수', 57), ('집', 51), ('저', 47), ('사람', 46), ('전화', 42), ('서구', 40), ('구청', 37), ('일', 36), ('말', 36), ('답변', 35)]
# [('소음', 36), ('집', 32), ('공단', 29), ('서구', 28), ('저', 27), ('명', 23), ('수', 23), ('대구', 22), ('동네', 21), ('저희', 20)]
# [('쓰레기', 96), ('음식물', 58), ('수거', 37), ('수', 28), ('집', 25), ('쓰레기통', 24), ('처리', 18), ('생각', 18), ('곳', 18), ('앞', 18)]
# [('도로', 1066), ('공사', 803), ('인도', 786), ('수', 634), ('앞', 589), ('설치', 587), ('차량', 481), ('주민', 470), ('길', 458), ('민원', 438)]
# [('쓰레기', 715), ('수거', 333), ('음식물', 251), ('수', 209), ('앞', 166), ('집', 138), ('활용', 134), ('일', 128), ('청소', 127), ('구청', 125)]
# [('주차', 3296), ('단속', 2138), ('차량', 2034), ('차', 1645), ('도로', 1497), ('불법', 1343), ('앞', 945), ('수', 911), ('주정차', 803), ('설치', 780)]
# [('수', 3384), ('수성', 3312), ('아파트', 3251), ('분양', 2988), ('공사', 2785), ('구청', 2489), ('입주', 2272), ('승인', 1788), ('일', 1528), ('문제', 1521)]
# [('소음', 795), ('공사', 719), ('수성', 370), ('민원', 361), ('수', 332), ('현장', 314), ('구청', 224), ('먼지', 223), ('진동', 222), ('주민', 216)]
# [('공원', 803), ('수성', 534), ('수', 508), ('설치', 376), ('주민', 336), ('등', 335), ('사람', 317), ('생각', 295), ('구청', 247), ('나무', 241)]
# [('주민', 116), ('쓰레기', 74), ('일', 70), ('수', 64), ('가로등', 60), ('센터', 54), ('민원', 51), ('분', 49), ('부탁', 47), ('앞', 47)]
# [('도로', 121), ('주민', 109), ('수', 84), ('불법', 84), ('구청', 82), ('수성', 80), ('민원', 74), ('인도', 71), ('앞', 68), ('현수막', 68)]
# [('모기', 115), ('보건소', 91), ('방역', 79), ('수', 75), ('수성구', 57), ('벌레', 42), ('검사', 39), ('때문', 38), ('수성', 34), ('병원', 33)]
# [('소음', 735), ('공사', 687), ('수', 466), ('아파트', 297), ('민원', 273), ('소리', 269), ('구청', 265), ('주민', 261), ('집', 253), ('현장', 233)]
# [('도서관', 343), ('수', 326), ('수성', 213), ('사람', 206), ('테니스장', 206), ('운영', 192), ('시간', 187), ('이용', 180), ('생각', 175), ('주민', 155)]
# [('수', 105), ('어린이집', 96), ('아이', 88), ('장애', 84), ('등', 81), ('구청', 72), ('수성', 69), ('고산', 66), ('학교', 62), ('원', 61)]

# %%
#가독성을 위해 딕셔너리 형태로
final_dic={}
for i in range(0,len(my_list)):
  final_dic[my_list[i]]=globals()['{}'.format(my_list[i])]

# %%
final_dic
# Out:
# {'BukGu_도시국_건설과': [('도로', 1197),
#   ('수', 1123),
#   ('건설', 966),
#   ('민원', 875),
#   ('분할', 800),
#   ('답변', 740),
#   ('공사', 726),
#   ('설치', 697),
#   ('당시', 641),
#   ('인도', 583)],
#  'BukGu_도시국_도시행정과': [('불법', 108),
#   ('단속', 97),
#   ('민원', 97),
#   ('물', 80),
#   ('광고', 72),
#   ('북구', 63),
#   ('시장', 57),
#   ('인도', 55),
#   ('앞', 52),
#   ('노점', 51)],
#  'BukGu_감사실': [('불법', 6189),
#   ('시장', 4369),
#   ('건축', 4052),
#   ('북', 3996),
#   ('행정', 3920),
#   ('구민', 3564),
#   ('구청장', 3173),
#   ('북구', 2863),
#   ('대구', 2806),
#   ('허가', 2656)],
#  'BukGu_도시국_건축주택과': [('수', 1784),
#   ('시설', 1763),
#   ('제조', 1753),
#   ('건축', 1738),
#   ('아파트', 1493),
#   ('제호', 1478),
#   ('등', 1437),
#   ('지역', 1259),
#   ('건축물', 1232),
#   ('별표', 1152)],
#  'BukGu_복지환경국_자원순환과': [('쓰레기', 817),
#   ('분리수거', 185),
#   ('행정', 182),
#   ('수거', 172),
#   ('처리', 169),
#   ('활용', 168),
#   ('북구', 167),
#   ('민원', 164),
#   ('투기', 155),
#   ('수', 144)],
#  'BukGu_복지환경국_환경관리과': [('소음', 478),
#   ('공사', 467),
#   ('쓰레기', 454),
#   ('수', 269),
#   ('민원', 247),
#   ('주민', 230),
#   ('아파트', 182),
#   ('현장', 176),
#   ('집', 166),
#   ('북구', 161)],
#  'BukGu_도시국_교통과': [('주차', 3408),
#   ('단속', 2172),
#   ('차량', 1774),
#   ('차', 1628),
#   ('불법', 1253),
#   ('도로', 1156),
#   ('수', 841),
#   ('앞', 799),
#   ('민원', 632),
#   ('아파트', 609)],
#  'BukGu_문화녹지국_공원녹지과': [('공원', 285),
#   ('나무', 131),
#   ('수', 106),
#   ('설치', 99),
#   ('북구', 94),
#   ('주민', 91),
#   ('공사', 89),
#   ('불편', 88),
#   ('가로수', 86),
#   ('앞', 83)],
#  'BukGu_읍/면/동사무소': [('주민', 215),
#   ('일', 137),
#   ('직원', 130),
#   ('센터', 127),
#   ('사람', 125),
#   ('말', 115),
#   ('수', 111),
#   ('제', 103),
#   ('동사무소', 97),
#   ('저', 93)],
#  'BukGu_도시국_도시관리과': [('공원', 442),
#   ('수', 275),
#   ('현수막', 224),
#   ('나무', 222),
#   ('주민', 212),
#   ('북구', 203),
#   ('가로수', 186),
#   ('등', 176),
#   ('사람', 166),
#   ('일', 158)],
#  'BukGu_주민생활지원국_환경관리과': [('쓰레기', 786),
#   ('수', 379),
#   ('소음', 339),
#   ('음식물', 333),
#   ('집', 304),
#   ('주민', 261),
#   ('공사', 250),
#   ('앞', 249),
#   ('일', 238),
#   ('수거', 230)],
#  'BukGu_도시국_재난안전과': [('불법', 519),
#   ('단속', 504),
#   ('노점상', 468),
#   ('시장', 298),
#   ('노점', 228),
#   ('사람', 225),
#   ('장사', 219),
#   ('동변동', 211),
#   ('일', 200),
#   ('인도', 190)],
#  'DalseongGun_건설도시국_건축과': [('아파트', 1023),
#   ('입주민', 655),
#   ('주차', 601),
#   ('분양', 578),
#   ('수', 547),
#   ('하나', 510),
#   ('달성', 504),
#   ('삼정', 498),
#   ('건설', 483),
#   ('군청', 473)],
#  'DalseongGun_건설도시국_안전총괄과': [('수', 127),
#   ('천', 93),
#   ('공사', 82),
#   ('달성군', 76),
#   ('설치', 73),
#   ('확진', 71),
#   ('주민', 66),
#   ('차량', 66),
#   ('사업', 62),
#   ('통행', 58)],
#  'DalseongGun_문화관광국_공원녹지과': [('공원', 249),
#   ('수', 143),
#   ('설치', 97),
#   ('길', 89),
#   ('사람', 81),
#   ('등', 80),
#   ('민원', 79),
#   ('곳', 70),
#   ('주민', 66),
#   ('쪽', 62)],
#  'DalseongGun_건설도시국_건설과': [('도로', 672),
#   ('멜', 502),
#   ('스노우', 460),
#   ('설치', 455),
#   ('협성', 453),
#   ('포레', 374),
#   ('휴', 345),
#   ('아파트', 322),
#   ('길', 322),
#   ('수', 288)],
#  'DalseongGun_경제환경국_교통과': [('주차', 523),
#   ('설치', 485),
#   ('단속', 470),
#   ('길', 458),
#   ('불법', 457),
#   ('차', 448),
#   ('차량', 399),
#   ('아이', 379),
#   ('주정차', 367),
#   ('스쿨', 367)],
#  'DalseongGun_교육복지국_교육정책과': [('어린이집', 101),
#   ('아이', 94),
#   ('수', 54),
#   ('증원', 42),
#   ('구지', 40),
#   ('도원', 39),
#   ('보육', 28),
#   ('곳', 27),
#   ('입소', 27),
#   ('일', 21)],
#  'DalseongGun_경제환경국_환경과': [('공사', 319),
#   ('소음', 312),
#   ('공장', 148),
#   ('민원', 135),
#   ('제지', 134),
#   ('수', 130),
#   ('주민', 126),
#   ('냄새', 122),
#   ('아파트', 110),
#   ('소리', 104)],
#  'DalseongGun_건설도시국_도시정비과': [('가로등', 95),
#   ('설치', 87),
#   ('민원', 63),
#   ('길', 62),
#   ('도로', 53),
#   ('수', 43),
#   ('공사', 41),
#   ('요청', 32),
#   ('주민', 30),
#   ('쪽', 29)],
#  'DalseongGun_읍/면/동사무소': [('쓰레기', 119),
#   ('민원', 104),
#   ('수', 95),
#   ('일', 89),
#   ('주민', 85),
#   ('살장', 82),
#   ('등', 75),
#   ('설치', 72),
#   ('요청', 63),
#   ('장', 63)],
#  'DalseongGun_자치행정국_종합민원과': [('공사', 38),
#   ('민원', 33),
#   ('에너지', 28),
#   ('허가', 26),
#   ('건물', 22),
#   ('저', 19),
#   ('생각', 18),
#   ('설치', 16),
#   ('도시', 16),
#   ('건축', 15)],
#  'DalseongGun_경제환경국_청소위생과': [('쓰레기', 75),
#   ('민원', 46),
#   ('수거', 45),
#   ('활용', 45),
#   ('냄새', 44),
#   ('수', 43),
#   ('공장', 36),
#   ('음식물', 32),
#   ('시간', 31),
#   ('사람', 31)],
#  'DalseongGun_문화관광국_문화예술과': [('달성', 83),
#   ('수', 68),
#   ('파크', 56),
#   ('달성군', 54),
#   ('시설', 46),
#   ('문화', 45),
#   ('군민', 42),
#   ('이용', 38),
#   ('년', 36),
#   ('골프장', 36)],
#  'DalseongGun_경제환경국_농업정책과': [('수', 68),
#   ('견', 45),
#   ('개', 41),
#   ('강아지', 40),
#   ('아파트', 36),
#   ('고양이', 34),
#   ('사람', 32),
#   ('민원', 32),
#   ('달성군', 31),
#   ('동물', 31)],
#  'DalseongGun_보건소_보건과': [('보건소', 110),
#   ('달성군', 76),
#   ('검사', 46),
#   ('수', 44),
#   ('전화', 41),
#   ('일', 38),
#   ('코로나', 37),
#   ('격리', 31),
#   ('병원', 29),
#   ('저', 27)],
#  'DalseongGun_건설도시국_도시계획과': [('도로', 54),
#   ('민원', 51),
#   ('가로등', 51),
#   ('공사', 45),
#   ('설치', 42),
#   ('길', 37),
#   ('불법', 32),
#   ('달성군', 29),
#   ('등', 28),
#   ('아파트', 26)],
#  'DalseongGun_건설도시국_교통과': [('차량', 156),
#   ('주차', 151),
#   ('도로', 137),
#   ('차', 127),
#   ('단속', 111),
#   ('불법', 104),
#   ('민원', 93),
#   ('수', 92),
#   ('버스', 82),
#   ('주정차', 82)],
#  'DalsuGu_도시창조국_공원녹지과': [('공원', 893),
#   ('수', 271),
#   ('설치', 232),
#   ('주민', 205),
#   ('아이', 195),
#   ('민원', 194),
#   ('사람', 164),
#   ('부탁', 157),
#   ('나무', 153),
#   ('이용', 151)],
#  'DalsuGu_경제환경국_청소과': [('쓰레기', 1276),
#   ('수거', 635),
#   ('음식물', 349),
#   ('앞', 317),
#   ('집', 284),
#   ('수', 272),
#   ('처리', 237),
#   ('활용', 237),
#   ('투기', 235),
#   ('불법', 233)],
#  'DalsuGu_경제환경국_주차관리과': [('주차', 3479),
#   ('단속', 2528),
#   ('차량', 2026),
#   ('불법', 1737),
#   ('차', 1711),
#   ('도로', 1231),
#   ('앞', 951),
#   ('주정차', 844),
#   ('수', 735),
#   ('민원', 712)],
#  'DalsuGu_경제환경국_교통행정과': [('차량', 193),
#   ('주차', 186),
#   ('설치', 174),
#   ('도로', 126),
#   ('차', 106),
#   ('민원', 84),
#   ('앞', 82),
#   ('불법', 75),
#   ('수', 68),
#   ('단속', 61)],
#  'DalsuGu_도시창조국_건설과': [('도로', 592),
#   ('공사', 470),
#   ('인도', 376),
#   ('길', 325),
#   ('수', 298),
#   ('설치', 291),
#   ('앞', 270),
#   ('가로등', 240),
#   ('차량', 222),
#   ('주민', 221)],
#  'DalsuGu_도시창조국_건축과': [('아파트', 719),
#   ('공사', 711),
#   ('수', 544),
#   ('관리', 374),
#   ('민원', 367),
#   ('구청', 362),
#   ('건축', 347),
#   ('등', 326),
#   ('일', 290),
#   ('집', 289)],
#  'DalsuGu_경제환경국_기후환경과': [('공사', 143),
#   ('소음', 134),
#   ('민원', 73),
#   ('아파트', 44),
#   ('소리', 43),
#   ('주말', 39),
#   ('거', 37),
#   ('주민', 35),
#   ('수', 34),
#   ('현장', 34)],
#  'DalsuGu_읍/면/동사무소': [('주민', 269),
#   ('센터', 187),
#   ('수', 171),
#   ('일', 167),
#   ('직원', 128),
#   ('사람', 125),
#   ('마스크', 120),
#   ('말', 114),
#   ('제', 113),
#   ('민원', 103)],
#  'DalsuGu_보건소_보건행정과': [('방역', 105),
#   ('바퀴벌레', 85),
#   ('모기', 66),
#   ('수', 61),
#   ('병원', 46),
#   ('거', 44),
#   ('코로나', 44),
#   ('부탁', 36),
#   ('확진', 36),
#   ('검사', 35)],
#  'DalsuGu_경제환경국_환경보호과': [('공사', 510),
#   ('소음', 495),
#   ('수', 194),
#   ('현장', 156),
#   ('민원', 147),
#   ('소리', 140),
#   ('시', 133),
#   ('때문', 132),
#   ('아파트', 130),
#   ('냄새', 124)],
#  'DalsuGu_도시창조국_도시재생과': [('불법', 116),
#   ('도로', 115),
#   ('앞', 107),
#   ('수', 100),
#   ('인도', 92),
#   ('단속', 85),
#   ('주차', 82),
#   ('사람', 78),
#   ('민원', 73),
#   ('불편', 63)],
#  'DalsuGu_복지문화국_문화체육관광과': [('수', 98),
#   ('구청', 83),
#   ('수영장', 67),
#   ('일', 61),
#   ('생각', 61),
#   ('사람', 60),
#   ('달서', 55),
#   ('민원', 55),
#   ('조형물', 55),
#   ('센터', 54)],
#  'DalsuGu_자치행정국_총무과': [('업무', 155),
#   ('정규직', 88),
#   ('구청', 85),
#   ('지속', 80),
#   ('일', 76),
#   ('답변', 75),
#   ('주민', 72),
#   ('수', 72),
#   ('공개', 71),
#   ('정보', 69)],
#  'DalsuGu_경제환경국_일자리경제과': [('수', 102),
#   ('시장', 86),
#   ('개', 78),
#   ('고양이', 72),
#   ('사람', 67),
#   ('일', 65),
#   ('구청', 62),
#   ('저', 51),
#   ('민원', 45),
#   ('문제', 42)],
#  'DalsuGu_경제환경국_녹색환경과': [('소음', 473),
#   ('공사', 442),
#   ('수', 221),
#   ('냄새', 176),
#   ('소리', 162),
#   ('주민', 150),
#   ('아파트', 146),
#   ('민원', 138),
#   ('시', 136),
#   ('집', 124)],
#  'DalsuGu_도시건설국_도시관리과': [('공원', 591),
#   ('수', 338),
#   ('앞', 249),
#   ('주민', 239),
#   ('사람', 237),
#   ('구청', 227),
#   ('단속', 222),
#   ('설치', 220),
#   ('불법', 202),
#   ('도로', 186)],
#  'DalsuGu_보건소_보건과': [('장례식장', 357),
#   ('주민', 325),
#   ('병원', 321),
#   ('말', 179),
#   ('사람', 172),
#   ('수', 163),
#   ('구청', 163),
#   ('보건소', 145),
#   ('우리', 127),
#   ('생각', 113)],
#  'DongGu_도시안전국_건설과': [('도로', 240),
#   ('민원', 147),
#   ('수', 144),
#   ('공사', 143),
#   ('길', 142),
#   ('설치', 137),
#   ('동구', 131),
#   ('앞', 128),
#   ('인도', 111),
#   ('주민', 110)],
#  'DongGu_도시안전국_교통과': [('주차', 1031),
#   ('단속', 561),
#   ('차량', 526),
#   ('차', 434),
#   ('불법', 344),
#   ('도로', 324),
#   ('수', 275),
#   ('주정차', 270),
#   ('설치', 262),
#   ('앞', 250)],
#  'DongGu_도시안전국_건축주택과': [('아파트', 736),
#   ('수', 734),
#   ('공사', 639),
#   ('세대', 574),
#   ('입주', 571),
#   ('아이', 510),
#   ('등', 503),
#   ('안전', 460),
#   ('학교', 381),
#   ('동대구', 357)],
#  'DongGu_도시안전국_도시과': [('현수막', 95),
#   ('불법', 65),
#   ('앞', 45),
#   ('수', 42),
#   ('민원', 40),
#   ('요청', 39),
#   ('설치', 39),
#   ('도로', 37),
#   ('동구', 34),
#   ('철거', 34)],
#  'DongGu_도시안전국_공원녹지과': [('공원', 205),
#   ('주민', 113),
#   ('설치', 103),
#   ('수', 90),
#   ('내', 84),
#   ('가로수', 74),
#   ('동구', 73),
#   ('이용', 70),
#   ('민원', 69),
#   ('길', 56)],
#  'DongGu_경제복지국_경제지원과': [('개', 83),
#   ('민원', 60),
#   ('수', 57),
#   ('일', 47),
#   ('동구', 40),
#   ('도시', 38),
#   ('사람', 36),
#   ('길', 36),
#   ('마리', 34),
#   ('구청', 31)],
#  'DongGu_경제복지국_환경녹색과': [('소음', 344),
#   ('쓰레기', 322),
#   ('공사', 311),
#   ('수거', 254),
#   ('집', 169),
#   ('주민', 165),
#   ('수', 158),
#   ('앞', 157),
#   ('민원', 149),
#   ('일', 124)],
#  'DongGu_보건소_보건의약과': [('보건소', 114),
#   ('동구', 96),
#   ('방역', 92),
#   ('모기', 67),
#   ('수', 67),
#   ('일', 67),
#   ('전화', 64),
#   ('격리', 58),
#   ('부탁', 40),
#   ('코로나', 39)],
#  'DongGu_읍/면/동사무소': [('주민', 134),
#   ('일', 130),
#   ('센터', 98),
#   ('저', 94),
#   ('사람', 93),
#   ('제', 92),
#   ('수', 87),
#   ('말', 79),
#   ('동사무소', 78),
#   ('직원', 77)],
#  'DongGu_행정문화국_행정지원과': [('설치', 96),
#   ('가로등', 87),
#   ('주민', 80),
#   ('수', 45),
#   ('집', 44),
#   ('동구', 39),
#   ('골목', 35),
#   ('센터', 30),
#   ('일', 29),
#   ('에너지', 29)],
#  'DongGu_복지생활국_환경자원과': [('쓰레기', 249),
#   ('소음', 165),
#   ('수거', 130),
#   ('수', 98),
#   ('동구', 98),
#   ('민원', 83),
#   ('주민', 80),
#   ('음식물', 79),
#   ('시', 78),
#   ('공사', 78)],
#  'DongGu_도시건설국_교통과': [('주차', 1401),
#   ('단속', 901),
#   ('차량', 858),
#   ('차', 740),
#   ('도로', 610),
#   ('불법', 482),
#   ('앞', 433),
#   ('수', 432),
#   ('동구', 338),
#   ('차선', 295)],
#  'DongGu_복지생활국_경제과': [('개', 68),
#   ('수', 65),
#   ('동구', 58),
#   ('일', 51),
#   ('시장', 51),
#   ('사람', 48),
#   ('생각', 44),
#   ('구청', 42),
#   ('저', 40),
#   ('집', 37)],
#  'DongGu_도시건설국_건설과': [('도로', 559),
#   ('앞', 363),
#   ('공사', 362),
#   ('수', 330),
#   ('가로등', 312),
#   ('길', 292),
#   ('설치', 291),
#   ('인도', 260),
#   ('사람', 257),
#   ('동구', 253)],
#  'DongGu_도시건설국_도시디자인과': [('불법', 84),
#   ('단속', 75),
#   ('현수막', 60),
#   ('도로', 46),
#   ('구청', 35),
#   ('민원', 35),
#   ('설치', 35),
#   ('조치', 34),
#   ('물', 34),
#   ('철거', 33)],
#  'DongGu_도시건설국_건축주택과': [('아파트', 901),
#   ('공사', 617),
#   ('수', 549),
#   ('동구', 535),
#   ('주민', 525),
#   ('승인', 404),
#   ('입주', 362),
#   ('분양', 350),
#   ('일', 338),
#   ('건물', 331)],
#  'DongGu_안전행정국_평생학습과': [('동구', 113),
#   ('수', 86),
#   ('도서관', 72),
#   ('이용', 46),
#   ('시설', 41),
#   ('생각', 40),
#   ('설치', 37),
#   ('저', 37),
#   ('운동', 35),
#   ('관광', 35)],
#  'DongGu_도시건설국_안전녹지과': [('공원', 180),
#   ('수', 95),
#   ('주민', 90),
#   ('아이', 88),
#   ('놀이터', 76),
#   ('동구', 74),
#   ('사람', 65),
#   ('신평동', 65),
#   ('설치', 64),
#   ('길', 58)],
#  'DongGu_주민생활지원국_환경청소과': [('쓰레기', 489),
#   ('음식물', 294),
#   ('수', 229),
#   ('소음', 204),
#   ('수거', 203),
#   ('집', 200),
#   ('사람', 185),
#   ('주민', 168),
#   ('앞', 165),
#   ('일', 160)],
#  'DongGu_도시건설국_도시공원과': [('공원', 178),
#   ('수', 101),
#   ('주민', 85),
#   ('설치', 82),
#   ('운동', 79),
#   ('사람', 74),
#   ('가로수', 74),
#   ('앞', 68),
#   ('동구', 67),
#   ('생각', 60)],
#  'JungGu_도시안전국_건설과': [('공사', 39),
#   ('수', 30),
#   ('민원', 30),
#   ('도로', 29),
#   ('앞', 28),
#   ('중구', 23),
#   ('조치', 22),
#   ('등', 20),
#   ('길', 19),
#   ('건물', 19)],
#  'JungGu_도시안전국_건축주택과': [('조합', 1057),
#   ('조합원', 845),
#   ('아파트', 821),
#   ('수', 774),
#   ('공개', 742),
#   ('중구', 629),
#   ('입주', 571),
#   ('더샵', 552),
#   ('대봉', 546),
#   ('등', 541)],
#  'JungGu_도시안전국_교통과': [('주차', 373),
#   ('단속', 186),
#   ('차량', 137),
#   ('차', 128),
#   ('불법', 93),
#   ('수', 92),
#   ('주정차', 84),
#   ('민원', 83),
#   ('도로', 80),
#   ('설치', 71)],
#  'JungGu_보건소_보건과': [('방역', 55),
#   ('모기', 49),
#   ('중구', 46),
#   ('민원', 39),
#   ('수', 31),
#   ('보건소', 31),
#   ('병원', 30),
#   ('중', 29),
#   ('사람', 26),
#   ('일', 24)],
#  'JungGu_관광경제국_환경자원과': [('소음', 47),
#   ('공사', 29),
#   ('사람', 23),
#   ('민원', 20),
#   ('새벽', 20),
#   ('시', 17),
#   ('쓰레기', 16),
#   ('때문', 15),
#   ('집', 15),
#   ('앞', 14)],
#  'JungGu_읍/면/동사무소': [('주민', 79),
#   ('사람', 54),
#   ('일', 45),
#   ('센터', 44),
#   ('발급', 41),
#   ('직원', 39),
#   ('말', 36),
#   ('제', 34),
#   ('저', 34),
#   ('서류', 33)],
#  'JungGu_관광경제국_문화교육과': [('청라', 300),
#   ('중구', 274),
#   ('체육', 211),
#   ('센터', 203),
#   ('명칭', 172),
#   ('국민', 141),
#   ('이름', 104),
#   ('지역', 101),
#   ('확정', 90),
#   ('대표', 81)],
#  'JungGu_기획예산실': [('중구', 83),
#   ('민원', 82),
#   ('청장', 52),
#   ('전화', 45),
#   ('청', 45),
#   ('일', 40),
#   ('구청', 38),
#   ('답변', 34),
#   ('통화', 34),
#   ('지명', 34)],
#  'JungGu_환경건설국_교통과': [('주차', 1371),
#   ('단속', 996),
#   ('차', 684),
#   ('차량', 638),
#   ('불법', 390),
#   ('사람', 335),
#   ('수', 313),
#   ('일', 311),
#   ('앞', 307),
#   ('도로', 294)],
#  'JungGu_환경건설국_건축주택과': [('공사', 104),
#   ('민원', 58),
#   ('소음', 57),
#   ('현장', 41),
#   ('수', 34),
#   ('시', 29),
#   ('아파트', 29),
#   ('남산', 28),
#   ('개발', 28),
#   ('문', 26)],
#  'JungGu_도시재생국_도시재생과': [('가로수', 42),
#   ('민원', 36),
#   ('사람', 34),
#   ('앞', 33),
#   ('광고', 32),
#   ('중', 32),
#   ('중구', 31),
#   ('불법', 30),
#   ('물', 29),
#   ('공사', 28)],
#  'JungGu_도시재생국_관광자원과': [('년', 57),
#   ('김광석', 53),
#   ('길', 52),
#   ('내용', 52),
#   ('수정', 47),
#   ('골목', 43),
#   ('오류', 40),
#   ('부분', 40),
#   ('중', 39),
#   ('수', 39)],
#  'JungGu_환경건설국_녹색환경과': [('쓰레기', 213),
#   ('수', 89),
#   ('공사', 86),
#   ('소음', 80),
#   ('수거', 73),
#   ('중', 72),
#   ('일', 59),
#   ('중구', 55),
#   ('앞', 53),
#   ('민원', 49)],
#  'JungGu_환경건설국_건설안전과': [('도로', 36),
#   ('민원', 27),
#   ('앞', 26),
#   ('곳', 22),
#   ('공사', 22),
#   ('수', 22),
#   ('설치', 20),
#   ('골목길', 20),
#   ('길', 20),
#   ('일', 19)],
#  'JungGu_도시관광국_건축주택과': [('중구', 909),
#   ('입주', 812),
#   ('수', 666),
#   ('아파트', 654),
#   ('중', 591),
#   ('승인', 561),
#   ('해링턴', 552),
#   ('구청', 524),
#   ('공사', 501),
#   ('플레이스', 499)],
#  'JungGu_행정지원국_경제과': [('일', 88),
#   ('중구', 76),
#   ('수', 73),
#   ('시장', 65),
#   ('말', 56),
#   ('원', 56),
#   ('분', 50),
#   ('중', 49),
#   ('구청', 49),
#   ('년', 46)],
#  'JungGu_안전행정국_경제과': [('중구', 492),
#   ('마트', 387),
#   ('시장', 360),
#   ('입점', 293),
#   ('대형', 268),
#   ('청', 180),
#   ('중', 147),
#   ('홈플러스', 146),
#   ('답변', 125),
#   ('수', 120)],
#  'JungGu_도시관광국_건설과': [('공사', 227),
#   ('도로', 140),
#   ('앞', 111),
#   ('민원', 85),
#   ('수', 79),
#   ('일', 72),
#   ('번', 67),
#   ('골목', 66),
#   ('인도', 64),
#   ('구청', 63)],
#  'JungGu_주민생활지원국_문화관광과': [('수', 52),
#   ('대구', 49),
#   ('청소년', 36),
#   ('중구', 34),
#   ('생각', 33),
#   ('저', 32),
#   ('일', 30),
#   ('중', 30),
#   ('골목', 29),
#   ('사람', 25)],
#  'JungGu_도시국_도시관리과': [('사람', 64),
#   ('중구', 55),
#   ('수', 52),
#   ('거리', 52),
#   ('대구', 49),
#   ('앞', 48),
#   ('가로수', 41),
#   ('인도', 38),
#   ('나무', 38),
#   ('도로', 36)],
#  'JungGu_주민생활지원국_환경과': [('쓰레기', 187),
#   ('사람', 73),
#   ('소음', 66),
#   ('음식물', 66),
#   ('수', 65),
#   ('일', 58),
#   ('공사', 51),
#   ('집', 49),
#   ('중구', 48),
#   ('처리', 48)],
#  'JungGu_총무국_총무과': [('주차', 114),
#   ('단속', 106),
#   ('차량', 81),
#   ('일', 59),
#   ('차', 57),
#   ('제', 57),
#   ('저', 56),
#   ('수', 55),
#   ('견인', 54),
#   ('스티커', 48)],
#  'NamGu_도시국_건설과': [('도로', 1197),
#   ('수', 1123),
#   ('건설', 966),
#   ('민원', 875),
#   ('분할', 800),
#   ('답변', 740),
#   ('공사', 726),
#   ('설치', 697),
#   ('당시', 641),
#   ('인도', 583)],
#  'NamGu_도시국_도시행정과': [('불법', 108),
#   ('단속', 97),
#   ('민원', 97),
#   ('물', 80),
#   ('광고', 72),
#   ('북구', 63),
#   ('시장', 57),
#   ('인도', 55),
#   ('앞', 52),
#   ('노점', 51)],
#  'NamGu_감사실': [('불법', 6178),
#   ('시장', 4368),
#   ('건축', 4045),
#   ('북', 3992),
#   ('행정', 3914),
#   ('구민', 3561),
#   ('구청장', 3172),
#   ('북구', 2859),
#   ('대구', 2802),
#   ('허가', 2653)],
#  'NamGu_도시국_건축주택과': [('수', 1784),
#   ('시설', 1763),
#   ('제조', 1753),
#   ('건축', 1738),
#   ('아파트', 1493),
#   ('제호', 1478),
#   ('등', 1437),
#   ('지역', 1259),
#   ('건축물', 1232),
#   ('별표', 1152)],
#  'NamGu_복지환경국_자원순환과': [('쓰레기', 817),
#   ('분리수거', 185),
#   ('행정', 182),
#   ('수거', 172),
#   ('처리', 169),
#   ('활용', 168),
#   ('북구', 167),
#   ('민원', 164),
#   ('투기', 155),
#   ('수', 144)],
#  'NamGu_복지환경국_환경관리과': [('소음', 478),
#   ('공사', 467),
#   ('쓰레기', 454),
#   ('수', 269),
#   ('민원', 247),
#   ('주민', 230),
#   ('아파트', 182),
#   ('현장', 176),
#   ('집', 166),
#   ('북구', 161)],
#  'NamGu_도시국_교통과': [('주차', 3408),
#   ('단속', 2172),
#   ('차량', 1774),
#   ('차', 1628),
#   ('불법', 1253),
#   ('도로', 1156),
#   ('수', 841),
#   ('앞', 799),
#   ('민원', 632),
#   ('아파트', 609)],
#  'NamGu_문화녹지국_공원녹지과': [('공원', 285),
#   ('나무', 131),
#   ('수', 106),
#   ('설치', 99),
#   ('북구', 94),
#   ('주민', 91),
#   ('공사', 89),
#   ('불편', 88),
#   ('가로수', 86),
#   ('앞', 83)],
#  'NamGu_읍/면/동사무소': [('주민', 215),
#   ('일', 137),
#   ('직원', 130),
#   ('센터', 127),
#   ('사람', 125),
#   ('말', 115),
#   ('수', 111),
#   ('제', 103),
#   ('동사무소', 97),
#   ('저', 93)],
#  'NamGu_도시국_도시관리과': [('공원', 442),
#   ('수', 275),
#   ('현수막', 224),
#   ('나무', 222),
#   ('주민', 212),
#   ('북구', 203),
#   ('가로수', 186),
#   ('등', 176),
#   ('사람', 166),
#   ('일', 158)],
#  'NamGu_주민생활지원국_환경관리과': [('쓰레기', 786),
#   ('수', 379),
#   ('소음', 339),
#   ('음식물', 333),
#   ('집', 304),
#   ('주민', 261),
#   ('공사', 250),
#   ('앞', 249),
#   ('일', 238),
#   ('수거', 230)],
#  'NamGu_도시국_재난안전과': [('불법', 519),
#   ('단속', 504),
#   ('노점상', 468),
#   ('시장', 298),
#   ('노점', 228),
#   ('사람', 225),
#   ('장사', 219),
#   ('동변동', 211),
#   ('일', 200),
#   ('인도', 190)],
#  'SeoGu_읍/면/동사무소': [('주차', 110),
#   ('주민', 88),
#   ('통장', 75),
#   ('수', 72),
#   ('사람', 64),
#   ('불법', 64),
#   ('일', 62),
#   ('집', 61),
#   ('앞', 56),
#   ('분', 51)],
#  'SeoGu_보건소_보건행정과': [('모기', 38),
#   ('방역', 33),
#   ('일', 24),
#   ('냄새', 22),
#   ('집', 21),
#   ('격리', 17),
#   ('서구', 16),
#   ('보건소', 15),
#   ('수', 14),
#   ('부탁', 14)],
#  'SeoGu_도시안전국_건축주택과': [('소음', 266),
#   ('층간', 248),
#   ('수', 247),
#   ('년', 233),
#   ('아파트', 213),
#   ('민원', 212),
#   ('답변', 207),
#   ('서구', 193),
#   ('공사', 188),
#   ('문제', 186)],
#  'SeoGu_도시안전국_교통과': [('주차', 396),
#   ('차', 199),
#   ('차량', 166),
#   ('단속', 142),
#   ('앞', 117),
#   ('도로', 114),
#   ('불법', 101),
#   ('서구', 93),
#   ('민원', 83),
#   ('설치', 82)],
#  'SeoGu_도시안전국_도시공원과': [('공원', 151),
#   ('길', 59),
#   ('나무', 59),
#   ('수', 57),
#   ('민원', 48),
#   ('도시', 44),
#   ('사람', 43),
#   ('철거', 43),
#   ('주민', 41),
#   ('서구', 40)],
#  'SeoGu_복지생활국_환경청소과': [('쓰레기', 291),
#   ('수거', 169),
#   ('수', 164),
#   ('민원', 145),
#   ('서구', 130),
#   ('악취', 126),
#   ('집', 112),
#   ('냄새', 106),
#   ('주민', 106),
#   ('앞', 100)],
#  'SeoGu_도시안전국_도시재생과': [('서구', 110),
#   ('전신주', 75),
#   ('민원', 73),
#   ('수', 71),
#   ('지중화', 58),
#   ('불법', 51),
#   ('등', 50),
#   ('주차', 44),
#   ('답변', 43),
#   ('사람', 42)],
#  'SeoGu_자치행정국_문화홍보과': [('서구', 63),
#   ('수', 35),
#   ('설치', 35),
#   ('주민', 31),
#   ('공원', 27),
#   ('구청', 24),
#   ('글', 24),
#   ('시간', 23),
#   ('민원', 22),
#   ('년', 22)],
#  'SeoGu_도시안전국_건설과': [('가로등', 110),
#   ('길', 80),
#   ('골목', 77),
#   ('도로', 71),
#   ('민원', 64),
#   ('집', 52),
#   ('공사', 49),
#   ('앞', 47),
#   ('서구', 44),
#   ('설치', 42)],
#  'SeoGu_자치행정국_총무과': [('서구', 90),
#   ('설치', 69),
#   ('일', 63),
#   ('집', 60),
#   ('주민', 57),
#   ('수', 56),
#   ('사람', 51),
#   ('직원', 49),
#   ('생각', 46),
#   ('구청', 43)],
#  'SeoGu_기획예산실': [('서구', 109),
#   ('민원', 58),
#   ('공무원', 37),
#   ('수', 23),
#   ('청', 23),
#   ('도서관', 23),
#   ('대구', 21),
#   ('주민', 21),
#   ('고충', 21),
#   ('업무', 20)],
#  'SeoGu_자치행정국_종합민원과': [('여권', 48),
#   ('사진', 45),
#   ('민원', 43),
#   ('구청', 40),
#   ('일', 38),
#   ('규정', 32),
#   ('수', 30),
#   ('민원인', 29),
#   ('레미콘', 29),
#   ('등', 26)],
#  'SeoGu_도시국_교통과': [('주차', 1056),
#   ('단속', 641),
#   ('차', 550),
#   ('차량', 456),
#   ('수', 298),
#   ('도로', 284),
#   ('불법', 273),
#   ('앞', 247),
#   ('일', 226),
#   ('견인', 199)],
#  'SeoGu_도시국_도시관리과': [('공원', 153),
#   ('가로등', 150),
#   ('주차', 133),
#   ('앞', 130),
#   ('수', 122),
#   ('사람', 114),
#   ('집', 107),
#   ('부탁', 96),
#   ('설치', 89),
#   ('주민', 86)],
#  'SeoGu_도시국_건설방재과': [('공사', 102),
#   ('도로', 97),
#   ('골목', 94),
#   ('수', 75),
#   ('앞', 74),
#   ('블럭', 68),
#   ('인도', 67),
#   ('자전거', 67),
#   ('길', 63),
#   ('차', 61)],
#  'SeoGu_주민생활지원국_경제과': [('오픈', 162),
#   ('수', 156),
#   ('서구', 155),
#   ('이마트', 152),
#   ('일', 150),
#   ('구청', 107),
#   ('사람', 107),
#   ('산점', 106),
#   ('도시', 89),
#   ('답변', 85)],
#  'SeoGu_주민생활지원국_환경관리과': [('쓰레기', 429),
#   ('집', 180),
#   ('수', 177),
#   ('냄새', 174),
#   ('사람', 168),
#   ('수거', 159),
#   ('주민', 147),
#   ('일', 141),
#   ('서구', 135),
#   ('민원', 133)],
#  'SeoGu_도시국_건축주택과': [('구청', 182),
#   ('수', 152),
#   ('집', 143),
#   ('민원', 133),
#   ('년', 132),
#   ('서구', 131),
#   ('주민', 130),
#   ('일', 123),
#   ('공사', 123),
#   ('사람', 93)],
#  'SeoGu_주민생활지원국_복지사업과': [('서구', 60),
#   ('수', 58),
#   ('일', 53),
#   ('저', 45),
#   ('시간', 42),
#   ('생각', 41),
#   ('제', 34),
#   ('말', 32),
#   ('복지', 30),
#   ('전화', 28)],
#  'SeoGu_도시국_건설과': [('도로', 38),
#   ('공사', 34),
#   ('집', 25),
#   ('땅', 22),
#   ('앞', 17),
#   ('차량', 16),
#   ('인도', 15),
#   ('시', 15),
#   ('수', 15),
#   ('평리동', 13)],
#  'SeoGu_기획감사실': [('수', 57),
#   ('집', 51),
#   ('저', 47),
#   ('사람', 46),
#   ('전화', 42),
#   ('서구', 40),
#   ('구청', 37),
#   ('일', 36),
#   ('말', 36),
#   ('답변', 35)],
#  'SeoGu_사회산업국_환경관리과': [('소음', 36),
#   ('집', 32),
#   ('공단', 29),
#   ('서구', 28),
#   ('저', 27),
#   ('명', 23),
#   ('수', 23),
#   ('대구', 22),
#   ('동네', 21),
#   ('저희', 20)],
#  'SeoGu_사회산업국_청소과': [('쓰레기', 96),
#   ('음식물', 58),
#   ('수거', 37),
#   ('수', 28),
#   ('집', 25),
#   ('쓰레기통', 24),
#   ('처리', 18),
#   ('생각', 18),
#   ('곳', 18),
#   ('앞', 18)],
#  'Suseonggu_도시국_건설과': [('도로', 1066),
#   ('공사', 803),
#   ('인도', 786),
#   ('수', 634),
#   ('앞', 589),
#   ('설치', 587),
#   ('차량', 481),
#   ('주민', 470),
#   ('길', 458),
#   ('민원', 438)],
#  'Suseonggu_복지국_자원순환과': [('쓰레기', 715),
#   ('수거', 333),
#   ('음식물', 251),
#   ('수', 209),
#   ('앞', 166),
#   ('집', 138),
#   ('활용', 134),
#   ('일', 128),
#   ('청소', 127),
#   ('구청', 125)],
#  'Suseonggu_도시국_교통과': [('주차', 3296),
#   ('단속', 2138),
#   ('차량', 2034),
#   ('차', 1645),
#   ('도로', 1497),
#   ('불법', 1343),
#   ('앞', 945),
#   ('수', 911),
#   ('주정차', 803),
#   ('설치', 780)],
#  'Suseonggu_도시국_건축과': [('수', 3384),
#   ('수성', 3312),
#   ('아파트', 3251),
#   ('분양', 2988),
#   ('공사', 2785),
#   ('구청', 2489),
#   ('입주', 2272),
#   ('승인', 1788),
#   ('일', 1528),
#   ('문제', 1521)],
#  'Suseonggu_복지국_녹색환경과': [('소음', 795),
#   ('공사', 719),
#   ('수성', 370),
#   ('민원', 361),
#   ('수', 332),
#   ('현장', 314),
#   ('구청', 224),
#   ('먼지', 223),
#   ('진동', 222),
#   ('주민', 216)],
#  'Suseonggu_도시국_공원녹지과': [('공원', 803),
#   ('수성', 534),
#   ('수', 508),
#   ('설치', 376),
#   ('주민', 336),
#   ('등', 335),
#   ('사람', 317),
#   ('생각', 295),
#   ('구청', 247),
#   ('나무', 241)],
#  'Suseonggu_읍/면/동사무소': [('주민', 116),
#   ('쓰레기', 74),
#   ('일', 70),
#   ('수', 64),
#   ('가로등', 60),
#   ('센터', 54),
#   ('민원', 51),
#   ('분', 49),
#   ('부탁', 47),
#   ('앞', 47)],
#  'Suseonggu_도시국_도시디자인과': [('도로', 121),
#   ('주민', 109),
#   ('수', 84),
#   ('불법', 84),
#   ('구청', 82),
#   ('수성', 80),
#   ('민원', 74),
#   ('인도', 71),
#   ('앞', 68),
#   ('현수막', 68)],
#  'Suseonggu_보건소_보건행정과': [('모기', 115),
#   ('보건소', 91),
#   ('방역', 79),
#   ('수', 75),
#   ('수성구', 57),
#   ('벌레', 42),
#   ('검사', 39),
#   ('때문', 38),
#   ('수성', 34),
#   ('병원', 33)],
#  'Suseonggu_복지국_경제환경과': [('소음', 735),
#   ('공사', 687),
#   ('수', 466),
#   ('아파트', 297),
#   ('민원', 273),
#   ('소리', 269),
#   ('구청', 265),
#   ('주민', 261),
#   ('집', 253),
#   ('현장', 233)],
#  'Suseonggu_교육문화국_문화체육과': [('도서관', 343),
#   ('수', 326),
#   ('수성', 213),
#   ('사람', 206),
#   ('테니스장', 206),
#   ('운영', 192),
#   ('시간', 187),
#   ('이용', 180),
#   ('생각', 175),
#   ('주민', 155)],
#  'Suseonggu_복지국_복지과': [('수', 105),
#   ('어린이집', 96),
#   ('아이', 88),
#   ('장애', 84),
#   ('등', 81),
#   ('구청', 72),
#   ('수성', 69),
#   ('고산', 66),
#   ('학교', 62),
#   ('원', 61)]}

# %%
#데이터 프레임으로!
mode_df=pd.DataFrame(final_dic)

# %%
mode_df.head(10)
# Out:
#   BukGu_도시국_건설과 BukGu_도시국_도시행정과    BukGu_감사실 BukGu_도시국_건축주택과  \
# 0    (도로, 1197)       (불법, 108)   (불법, 6189)       (수, 1784)
# 1     (수, 1123)        (단속, 97)   (시장, 4369)      (시설, 1763)
# 2     (건설, 966)        (민원, 97)   (건축, 4052)      (제조, 1753)
# 3     (민원, 875)         (물, 80)    (북, 3996)      (건축, 1738)
# 4     (분할, 800)        (광고, 72)   (행정, 3920)     (아파트, 1493)
# 5     (답변, 740)        (북구, 63)   (구민, 3564)      (제호, 1478)
# 6     (공사, 726)        (시장, 57)  (구청장, 3173)       (등, 1437)
# 7     (설치, 697)        (인도, 55)   (북구, 2863)      (지역, 1259)
# 8     (당시, 641)         (앞, 52)   (대구, 2806)     (건축물, 1232)
# 9     (인도, 583)        (노점, 51)   (허가, 2656)      (별표, 1152)
#
#   BukGu_복지환경국_자원순환과 BukGu_복지환경국_환경관리과 BukGu_도시국_교통과 BukGu_문화녹지국_공원녹지과  \
# 0        (쓰레기, 817)         (소음, 478)    (주차, 3408)         (공원, 285)
# 1       (분리수거, 185)         (공사, 467)    (단속, 2172)         (나무, 131)
# 2         (행정, 182)        (쓰레기, 454)    (차량, 1774)          (수, 106)
# 3         (수거, 172)          (수, 269)     (차, 1628)          (설치, 99)
# 4         (처리, 169)         (민원, 247)    (불법, 1253)          (북구, 94)
# 5         (활용, 168)         (주민, 230)    (도로, 1156)          (주민, 91)
# 6         (북구, 167)        (아파트, 182)      (수, 841)          (공사, 89)
# 7         (민원, 164)         (현장, 176)      (앞, 799)          (불편, 88)
# 8         (투기, 155)          (집, 166)     (민원, 632)         (가로수, 86)
# 9          (수, 144)         (북구, 161)    (아파트, 609)           (앞, 83)
#
#   BukGu_읍/면/동사무소 BukGu_도시국_도시관리과  ... Suseonggu_도시국_교통과 Suseonggu_도시국_건축과  \
# 0      (주민, 215)       (공원, 442)  ...        (주차, 3296)         (수, 3384)
# 1       (일, 137)        (수, 275)  ...        (단속, 2138)        (수성, 3312)
# 2      (직원, 130)      (현수막, 224)  ...        (차량, 2034)       (아파트, 3251)
# 3      (센터, 127)       (나무, 222)  ...         (차, 1645)        (분양, 2988)
# 4      (사람, 125)       (주민, 212)  ...        (도로, 1497)        (공사, 2785)
# 5       (말, 115)       (북구, 203)  ...        (불법, 1343)        (구청, 2489)
# 6       (수, 111)      (가로수, 186)  ...          (앞, 945)        (입주, 2272)
# 7       (제, 103)        (등, 176)  ...          (수, 911)        (승인, 1788)
# 8     (동사무소, 97)       (사람, 166)  ...        (주정차, 803)         (일, 1528)
# 9        (저, 93)        (일, 158)  ...         (설치, 780)        (문제, 1521)
#
#   Suseonggu_복지국_녹색환경과 Suseonggu_도시국_공원녹지과 Suseonggu_읍/면/동사무소  \
# 0           (소음, 795)           (공원, 803)          (주민, 116)
# 1           (공사, 719)           (수성, 534)          (쓰레기, 74)
# 2           (수성, 370)            (수, 508)            (일, 70)
# 3           (민원, 361)           (설치, 376)            (수, 64)
# 4            (수, 332)           (주민, 336)          (가로등, 60)
# 5           (현장, 314)            (등, 335)           (센터, 54)
# 6           (구청, 224)           (사람, 317)           (민원, 51)
# 7           (먼지, 223)           (생각, 295)            (분, 49)
# 8           (진동, 222)           (구청, 247)           (부탁, 47)
# 9           (주민, 216)           (나무, 241)            (앞, 47)
#
#   Suseonggu_도시국_도시디자인과 Suseonggu_보건소_보건행정과 Suseonggu_복지국_경제환경과  \
# 0            (도로, 121)           (모기, 115)           (소음, 735)
# 1            (주민, 109)           (보건소, 91)           (공사, 687)
# 2              (수, 84)            (방역, 79)            (수, 466)
# 3             (불법, 84)             (수, 75)          (아파트, 297)
# 4             (구청, 82)           (수성구, 57)           (민원, 273)
# 5             (수성, 80)            (벌레, 42)           (소리, 269)
# 6             (민원, 74)            (검사, 39)           (구청, 265)
# 7             (인도, 71)            (때문, 38)           (주민, 261)
# 8              (앞, 68)            (수성, 34)            (집, 253)
# 9            (현수막, 68)            (병원, 33)           (현장, 233)
#
#   Suseonggu_교육문화국_문화체육과 Suseonggu_복지국_복지과
# 0            (도서관, 343)          (수, 105)
# 1              (수, 326)        (어린이집, 96)
# 2             (수성, 213)          (아이, 88)
# 3             (사람, 206)          (장애, 84)
# 4           (테니스장, 206)           (등, 81)
# 5             (운영, 192)          (구청, 72)
# 6             (시간, 187)          (수성, 69)
# 7             (이용, 180)          (고산, 66)
# 8             (생각, 175)          (학교, 62)
# 9             (주민, 155)           (원, 61)
#
# [10 rows x 134 columns]

# %%
# mode_df.to_csv('mode_data.csv',index=False)
mode_df.to_csv('/content/drive/MyDrive/벨류업 프로젝트 공모전/mode_data.csv',index=False)
